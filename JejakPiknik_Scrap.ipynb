# %% [markdown]
# # Scraping Data Dari Web jejakpiknik.com

# %%
# Import library yang akan digunakan untuk scraping
import requests  # Import library requests untuk mengambil data dari website
from bs4 import BeautifulSoup # Import BeautifulSoup dari bs4 untuk mem-parsing HTML
import pandas as pd  # Import pandas untuk mengolah data dalam bentuk tabel (DataFrame)
import re  # Import re (regular expression) untuk pencarian pola teks dalam HTML

# %%
# Daftar semua URL halaman wisata yang akan di-scrape
urls = [
    "https://jejakpiknik.com/tempat-wisata-di-bandung/",
    "https://jejakpiknik.com/wisata-alam-bandung/",
    "https://jejakpiknik.com/destinasi-wisata-bandung/",
    "https://jejakpiknik.com/tempat-rekreasi-di-bandung/",
    "https://jejakpiknik.com/tempat-liburan-di-bandung/",
    "https://jejakpiknik.com/tempat-wisata-di-lembang/",
    "https://jejakpiknik.com/wisata-lembang/",
    "https://jejakpiknik.com/wisata-ciwidey/"
]
# Definisikan fungsi untuk mengambil nama tempat dari setiap URL
# Fungsi ini mengambil teks dari tag <h3> yang mengandung angka di awal kalimat
def ambil_nama_tempat(url):
    res = requests.get(url)  # Mengirim permintaan HTTP ke URL
    soup = BeautifulSoup(res.text, "html.parser")  # Parsing HTML dari hasil permintaan
    konten = soup.find("div", class_="entry-content clear")  # Cari konten utama
    hasil = []  # List kosong untuk menyimpan hasil
    if konten:
        for tag in konten.find_all("h3"):  # Ambil semua tag <h3> dalam konten
            text = tag.get_text(strip=True)  # Ambil teks tanpa spasi awal/akhir
            if any(char.isdigit() for char in text[:4]):  # Cek apakah ada angka di awal (misal "1.")
                hasil.append(text)  # Simpan teks yang cocok
    return hasil  # Kembalikan list hasil

#  Loop ke semua URL dan kumpulkan hasil dari tiap halaman
semua_mentah = []  # Inisialisasi list kosong untuk semua hasil mentah
for url in urls:
    tempat = ambil_nama_tempat(url)  # Panggil fungsi scraping untuk tiap URL
    semua_mentah.extend(tempat)  # Tambahkan hasil ke list utama

# Cetak 60 hasil mentah yang telah dikumpulkan
print("Data mentah:")
for i in range(60):
    print("-", semua_mentah[i])
# Out:
# Data mentah:
# - 1. Curug Tilu Leuwi Opat❤️
# - 2. Curug Malela❤️
# - 3. Gunung Artapela❤️
# - 4. Gunung Nini❤️
# - 5. Saung Angklung Mang Udjo❤️
# - 6. Situ Cisanti❤️
# - 7. Bukit Gantole Cililin❤️
# - 8. Curug Cimahi❤️
# - 9. Situ Cileunca❤️
# - 10. Ciwangun Indah Camp❤️
# - 11. Pemandian Air Panas Ciater❤️
# - 12. Puncak Ciumbuleuit❤️
# - 13. Bandung Treetop Adventure Park❤️
# - 14. Terminal Wisata Grafika Cikole❤️
# - 16. Situ Lembang❤️
# - 17. Stone Garden Geo Park❤️
# - 18. Bukit Moko❤️
# - 19. NuArt Sculpture Park❤️
# - 20. Pine Forest Camp❤️
# - 21. Gua Pawon❤️
# - 22. Taman Bunga Cihideung❤️
# - 23. Babakan Siliwangi❤️
# - 24. Bukit Teletubies❤️
# - 25. Sanghyang Poek❤️
# - 26. Kawah Rengganis❤️
# - 27. Kampung Batu Malakasari❤️
# - 28.GunungPuntang❤️
# - 29. Bukit Bintang❤️
# - 30. Desa Wisata Kampung Pasir Angling❤️
# - 31. Curug Bellarosa❤️
# - 32. Sendang Geulis Kahuripan❤️
# - 33. Amazing Art World❤️
# - 34. Upside Down World❤️
# - 35. Curug Bugbrug❤️
# - 36. Museum Geologi❤️
# - 37. Kebun Binatang Bandung❤️
# - 38. Kebun Teh Sukawana❤️
# - 39. Taman Hutan Raya Ir.H Djuanda❤️
# - 40. Trans Studio Bandung❤️
# - 41. Farmhouse Susu Lembang❤️
# - 42. Gunung Tangkuban Perahu❤️
# - 43. Floating Market❤️
# - 44. Taman Miniatur Kereta Api❤️
# - 45. Sapu Lidi Resort❤️
# - 46. Jendela Alam Lembang❤️
# - 47. Kampung Gajah Wonderland❤️
# - 48. Observatorium Bosscha❤️
# - 49.GunungPutri❤️
# - 50. Maribaya Natural Hot Spring Resort❤️
# - 51. Taman Begonia❤️
# - 52. Taman Lembah Dewata❤️
# - 53. Balitsa Lembang❤️
# - 54. Bukit Tunggul Cibodas❤️
# - 55. De Ranch❤️
# - 56. Dusun Bambu Lembang❤️
# - 57. Kawah Putih Ciwidey❤️
# - 58. Bukit Jamur❤️
# - 59. Situ Patenggang❤️
# - 60. Ranca Upas❤️
# - 61. Ciwidey Valley Hot Spring Waterpark Resort❤️

# %% [markdown]
# # Pembersihan Data Hasil Scraping

# %%
# Atur tampilan DataFrame agar tidak terpotong saat ditampilkan
pd.set_option('display.width', None)
pd.set_option('display.max_columns', None)

# Siapkan list penampung untuk tiap kategori data
judul_list = []   # Nama tempat wisata
alamat_list = []  # Alamat lokasi
harga_list = []   # Harga tiket masuk
telp_list = []    # Nomor telepon
jam_list = []     # Jam operasional

# Fungsi untuk ekstrak info penting dari deskripsi HTML (alamat, harga, telp, jam)
def extract_info(soup):
    # Default isi jika tidak ditemukan
    alamat = harga = telp = jam = "Tidak tersedia"

    # Telusuri semua tag <strong> dalam deskripsi
    for s in soup.find_all("strong"):
        label = s.get_text(strip=True).lower()

        # Ambil teks setelah <strong> (bisa sebagai sibling atau dalam <p>/<li>)
        next_text = ""
        if s.next_sibling and isinstance(s.next_sibling, str):
            next_text = s.next_sibling.strip()
        elif s.parent and s.parent.name in ["p", "li"]:
            full = s.parent.get_text(" ", strip=True)
            after = re.sub(s.get_text(strip=True), "", full, flags=re.I).strip()
            next_text = after

        # Cocokkan isi berdasarkan label
        if "alamat" in label and "koordinat" not in label:
            alamat = next_text or alamat
        elif "harga" in label or "tarif" in label:
            harga = next_text or harga
        elif "telp" in label or "telepon" in label:
            match = re.search(r"(\+62|0)[\d\s\-()]{7,}", next_text)
            telp = match.group() if match else next_text
        elif "jam" in label or "operasional" in label or "buka" in label:
            jam = next_text or jam

    return alamat.strip(), harga.strip(), telp.strip(), jam.strip()

# Loop ke semua URL dan ambil semua data tempat wisata
for url in urls:
    print(f"Scraping: {url}")
    res = requests.get(url)  # Kirim permintaan HTTP
    soup = BeautifulSoup(res.text, "html.parser")  # Parsing HTML
    konten = soup.find("div", class_="entry-content clear")  # Ambil bagian utama artikel

    if konten:
        h3_tags = konten.find_all("h3")  # Ambil semua tag <h3>
        for h3 in h3_tags:
            text = h3.get_text(strip=True)
            if re.match(r"^\d+\.", text):  # Hanya proses jika format: 1. Nama Tempat
                nama = re.sub(r"^\d+\.\s*", "", text).replace("❤️", "").strip()
                # Ambil deskripsi yang muncul setelah <h3> sampai <h3> berikutnya
                next_tag = h3.find_next_sibling()
                desc_block = ""
                while next_tag and next_tag.name != "h3":
                    if next_tag.name in ["p", "li"]:
                        desc_block += str(next_tag)
                    next_tag = next_tag.find_next_sibling()

                # Ekstrak info dari blok deskripsi menggunakan BeautifulSoup dan fungsi extract_info()
                temp_soup = BeautifulSoup(desc_block, "html.parser")
                alamat, harga, telp, jam = extract_info(temp_soup)

                # Tambahkan hasil ke masing-masing list
                judul_list.append(nama)
                alamat_list.append(alamat)
                harga_list.append(harga)
                telp_list.append(telp)
                jam_list.append(jam)

# Buat DataFrame dari hasil yang dikumpulkan
df = pd.DataFrame({
    "Nama Tempat": judul_list,
    "Alamat": alamat_list,
    "Harga/Tiket": harga_list,
    "No. Telp": telp_list,
    "Jam Operasional": jam_list
})

# Tampilkan jumlah data dan seluruh DataFrame (tanpa index disembunyikan)
print(f"\nJumlah tempat ditemukan: {len(df)}\n")
print(df.to_string(index=True))
# Out:
# Scraping: https://jejakpiknik.com/tempat-wisata-di-bandung/
# Scraping: https://jejakpiknik.com/wisata-alam-bandung/
# Scraping: https://jejakpiknik.com/destinasi-wisata-bandung/
# Scraping: https://jejakpiknik.com/tempat-rekreasi-di-bandung/
# Scraping: https://jejakpiknik.com/tempat-liburan-di-bandung/
# Scraping: https://jejakpiknik.com/tempat-wisata-di-lembang/
# Scraping: https://jejakpiknik.com/wisata-lembang/
# Scraping: https://jejakpiknik.com/wisata-ciwidey/
#
# Jumlah tempat ditemukan: 60
#
#                                    Nama Tempat                                                                                             Alamat                                                                                                                           Harga/Tiket                     No. Telp                                                                   Jam Operasional
# 0                        Curug Tilu Leuwi Opat                          Jl. Kp. Ciwangun Indah Camp, Desa Cihanjuang Rahayu, Kecamatan Parongpong                                                                                                                             Rp.10.000               0812-2224-6821                                                                 06.00 – 18.00 WIB
# 1                                 Curug Malela                                                         Desa Cicadas, Kecamatan Rongga Gunung Halu                                                                                                                             Rp.10.000               Tidak tersedia                                                                            24 Jam
# 2                              Gunung Artapela                                                                 Desa Sukapura, Kecamatan Kertasari                                                                                                                              Rp.5.000               0812-2380-3013                                                                 08.00 – 17.00 WIB
# 3                                  Gunung Nini                                      Perkebunan Teh Malabar, Desa Margaluyu, Kecamatan Pangalengan                                                                                                                              Rp.5.000               Tidak tersedia                                                                            24 Jam
# 4                     Saung Angklung Mang Udjo                    Jl. Padasuka No.116, Desa Pasirlayung, Kecamatan Cibeunying Kidul, Kota Bandung                                                                                      Senin- Jumat Rp.60.000, Sabtu – Minggu Rp.75.000                 022) 7271714                                                                 09.00 – 15.30 WIB
# 5                                 Situ Cisanti                                                               Desa Tarumajaya, Kecamatan Kertasari                                                                                                                              Rp.7.500               Tidak tersedia                                                                 08.00 – 17.00 WIB
# 6                        Bukit Gantole Cililin                                                               Desa Singajaya, Kecamatan Cihampelas                                                                                                                                Gratis               Tidak tersedia                                                                            24 Jam
# 7                                 Curug Cimahi                                            Jl. Kolonel Masturi, Desa Kertawangi, Kecamatan Cisarua                                                                                                                              Rp.15000               Tidak tersedia                                                                 08.00 – 21.00 WIB
# 8                                Situ Cileunca                                                              Desa Warnasari, Kecamatan Pangalengan                                                                                                                             Rp.10.000               Tidak tersedia                                                                            24 Jam
# 9                          Ciwangun Indah Camp                      JL. Kolonel Masturi RT.03 RW.15, Desa Cihanjuang Rahayu, Kecamatan Parongpong                                                                                                                              Rp.7.000                022) 61005867                                                                 07.00 – 19.30 WIB
# 10                  Pemandian Air Panas Ciater                                   JL. Raya Ciater, Desa Nagrak, Kecamatan Ciater, Kabupaten Subang                                                                                                                  Mulai dari Rp.15.000                 0260) 471700                                                                            24 Jam
# 11                          Puncak Ciumbuleuit                            JL. Rereongan Sarupi, Desa Ciumbuleuit, Kecamatan Cidadap, Kota Bandung                                                                                                                        Tidak tersedia               Tidak tersedia                                                                 08.00 – 00.00 WIB
# 12              Bandung Treetop Adventure Park                                    Cikole Jayagiri Resort, JL. Tangkuban Perahu Km.28, Desa Cikole                                                                                                                  Mulai dari Rp.10.000                022) 82780672                                                                 08.00 – 16.30 WIB
# 13              Terminal Wisata Grafika Cikole                                                            JL. Tangkuban Perahu Km. 8, Desa Cikole                                                                                                                                Gratis                022) 82782441                                                                 08.00 – 22.00 WIB
# 14                                Situ Lembang                                                              Desa Karyawangi, Kecamatan Parongpong                                                                                                                             Rp.10.000               Tidak tersedia                                                                 08.00 – 17.00 WIB
# 15                       Stone Garden Geo Park                                                            Desa Gunung Massigit, Kecamatan Cipatat                                                                                                                             Rp.10.000               Tidak tersedia                                                                 08.00 – 17.00 WIB
# 16                                  Bukit Moko                                                                                           Cimenyan                                                                                                                                Gratis               Tidak tersedia                                                                            24 Jam
# 17                        NuArt Sculpture Park                                                                  JL. Setraduta Raya No.L6 Ciwaruga                                                                                                                                Gratis                 022) 2025812                                                                 09.00 – 21.00 WIB
# 18                            Pine Forest Camp                JL. Maribaya Timur, Kampung Cibeunying Kaler, Desa Cibodas, Kabupaten Bandung Barat                                                                                                  Harga Paket Camping mulai Rp.150.000                 022) 5204292                                                                            24 Jam
# 19                                   Gua Pawon                                                 Gunung Masigit, Desa Cipatat, Kecamatan Padalarang                                                                                                                             Rp.10.000               Tidak tersedia                                                                 08.00 – 17.00 WIB
# 20                       Taman Bunga Cihideung                                   JL. Kolonel Masturi No.223, Desa Cihideung, Kecamatan Parongrong                                                                                                                        Tidak tersedia                022) 278 5154                                                                 08.00 – 17.00 WIB
# 21                           Babakan Siliwangi                                             JL. Siliwangi No.7, Lebak Siliwangi, Kecamatan Coblong                                                                                                                              Rp.3.000                 022) 2501394                                                                            24 Jam
# 22                            Bukit Teletubies                                 JL. Siliwangi No.7, Lebak Siliwangi, Kecamatan Coblong, Jawa Barat                                                                                                                                Gratis               Tidak tersedia                                                                            24 Jam
# 23                              Sanghyang Poek  JL. PLTA Saguling, Desa Rajamandala Kulon, Kecamatan Cipatat, Kabupaten Bandung Barat, Jawa Barat                                                                                                                        Tidak tersedia               Tidak tersedia                                                                    Tidak tersedia
# 24                             Kawah Rengganis                                                                 Desa Patengan, Kecamatan Rancabali                                                                                                                              Rp.5.000               Tidak tersedia                                                                 08.00 – 17.00 WIB
# 25                     Kampung Batu Malakasari                                  JL. Raya Banjaran (Rencong), Desa Malakasari, Kecamatan Baleendah  Paket Wisata Pelajar Rp.90.000/Orang, Smart & Creatif Rp.110.000/Orang, Goyang Leutak Rp.85.000/Orang, Lembur Kuring Rp.95.000/Orang                022) 72591042                                                                 08.00 – 18.00 WIB
# 26                               GunungPuntang                                                                 Desa Mekarjaya, Kecamatan Banjaran                                                                                                                              Rp.4.000               Tidak tersedia                                                                            24 Jam
# 27                               Bukit Bintang                                                                 Desa Mekarjaya, Kecamatan Banjaran                                                                                               Hari Biasa Rp.2000, Hari Libur Rp.3.000               0819-1005-4134                                                                            24 Jam
# 28           Desa Wisata Kampung Pasir Angling                                                                Desa Sunten Jaya, Kecamatan Cibodas                                                                                                                                Gratis               0852-1886-1522                                                                            24 Jam
# 29                             Curug Bellarosa       JL. Maribaya Timur, Desa Sunten Jaya, Kecamatan Cibodas, Kabupaten Bandung Barat, Jawa Barat                                                                                                                               Rp.5000               Tidak tersedia                                                                            24 Jam
# 30                    Sendang Geulis Kahuripan                                                          Desa Ganjarsari, Kecamatan Cikalong Wetan                                                                                                                             Rp.10.000               0852-9544-7036                                                                 07.00 – 17.00 WIB
# 31                           Amazing Art World                                               JL. Setiabudi No.293, Desa Isola, Kecamatan Sukasari                                                                              Anak-anak Rp.80.000, Pelajar Rp.100.000, Umum Rp.150.000                 022) 2025280                                                                 09.00 – 21.00 WIB
# 32                           Upside Down World                                 JL. H. Wasid No.31 (Dipatiukur), Desa Lebakgede, Kecamatan Coblong                                                                                                Anak-anak Rp.50.000, Dewasa Rp.100.000                022) 20454234                                                                 10.00 – 20.00 WIB
# 33                               Curug Bugbrug                                JL. Kolonel Masturi, Desa Kertawangi, Kecamatan Cisarua, Jawa Barat                                                                                                                              Rp.7.500               Tidak tersedia                                                                 09.00 – 16.00 WIB
# 34                              Museum Geologi                               JL. Diponegoro No.57, Desa Cihaur Geulis, Kecamatan Cibeunying Kaler                                                                  Pelajara Rp.2000, Wisatawan Lokal Rp.3000, Wisatawan Asing Rp.10.000                 022) 7213822                Senin – Jumat 08.00 – 16.00 WIB, Sabtu – Minggu  08.00 – 14.00 WIB
# 35                      Kebun Binatang Bandung                                  JL. Kebun Binatang No.06, Desa Lebak Siliwangi, Kecamatan Coblong                                                                                                 Anak-anak Rp.15.000, Dewasa Rp.20.000                 022) 2502770                                                                 08.00 – 17.00 WIB
# 36                          Kebun Teh Sukawana                                     Desa Karyawangi, Kecamatan Parongpong, Kabupaten Bandung Barat                                                                                            Tiket Rp.5.000, Camping Rp.10.000 perorang               Tidak tersedia                                                                            24 Jam
# 37               Taman Hutan Raya Ir.H Djuanda                 Kompleks Tahura Ir.H. Djuanda No.99, Dago Pakar, Desa Ciburial, Kecamatan Cimenyan                                                                               Wisatawan Domestik Rp.11.000, Wisatawan Manca Rp.76.000                 022) 2515895                                                                 06.00 – 18.00 WIB
# 38                        Trans Studio Bandung                          JL. Jenderal Gatot Subroto No.289, Desa Cibangkong, Kecamatan Batununggal                                                                    Senin – Jumat Rp.150.000, Sabtu – Minggu dan Hari Libur Rp.250.000   022) 86012555 087821054789  Senin – Jumat 10.00 – 19.00 WIB, Sabtu – Minggu dan Hari Libur 09.00 – 21.00 WIB
# 39                      Farmhouse Susu Lembang                                                                                     Tidak tersedia                                                                                  Rp.10.000 (Bisa ditukar dengan makanan atau minuman)                022) 82782400                                                                  09.00 –21.00 WIB
# 40                     Gunung Tangkuban Perahu                                                                                     Tidak tersedia                                                                                                                        Tidak tersedia               Tidak tersedia                                                                            24 Jam
# 41                             Floating Market                                                          JL. Grand Hotel No.33E, Kecamatan Lembang                                                                                                                             Rp.15.000                 022) 2787766                Senin – Kamis 09.00 – 19.00 WIB, Jum’at – Minggu 09.00 – 20.00 WIB
# 42                   Taman Miniatur Kereta Api                                                          JL. Grand Hotel No.33E, Kecamatan Lembang                                                                                                                             Rp.25.000                 022) 2787766                Senin – Kamis 09.00 – 19.00 WIB, Jum’at – Minggu 09.00 – 20.00 WIB
# 43                            Sapu Lidi Resort       Kompleks Graha Puspa, JL. Sersan Bajuri, Dusun Cihideung, Desa Parongpong, Kecamatan Lembang                                                                                                                        Tidak tersedia  022) 2786915 0812-2436-5169                                                                 08.00 – 22.00 WIB
# 44                        Jendela Alam Lembang  Komplek Graha Puspa, JL. Sersan Bajuri Km.45, Dusun Cihideung, Desa Parongpong, Kecamatan Lembang                                                                                                                             Rp.15.000                 022) 2788482                                                                 09.00 – 16.00 WIB
# 45                    Kampung Gajah Wonderland                       JL. Sersan Bajuri Km.38, Dusun Cihideung, Desa Parongpong, Kecamatan Lembang                                                                      Senin – Kamis Rp.10.000, Jumat – Minggu dan hari Libur Rp.20.000                022) 88884012                                                                 08.00 – 17.00 WIB
# 46                       Observatorium Bosscha                                                          JL. Peneropong Bintang, Kecamatan Lembang                                                                                                                   Mulai dari Rp.7.500                 022) 2786001                                                                 09.00 – 13.00 WIB
# 47                                 GunungPutri                                                 JL. Gunung Putri, Desa Jayagiri, Kecamatan Lembang                                                                                                                   Mulai dari Rp.5.000               0852-1886-1522                                                                 08.00 – 17.00 WIB
# 48          Maribaya Natural Hot Spring Resort                                                                                     Tidak tersedia                                                                                                                             Rp.35.000                 022) 8278228                                                                 08.00 – 20.00 WIB
# 49                               Taman Begonia                                          JL. Raya Maribaya No.120A, Desa Cibogo, Kecamatan Lembang                                                                                                                             Rp.10.000                 022) 2788527                                                                 08.00 – 17.30 WIB
# 50                         Taman Lembah Dewata                                         JL. Tangkuban Perahu Km.37, Desa Cibogo, Kecamatan Lembang                                                                                                                             Rp.10.000               0812-2253-6000                                                                 08.00 – 17.00 WIB
# 51                             Balitsa Lembang                                                     JL. Tangkuban Perahu No.517, Kecamatan Lembang                                                                                                                                Gratis                022) 22786025                                                                 08.00 – 17.00 WIB
# 52                       Bukit Tunggul Cibodas                                                                    Desa Cibodas, Kecamatan Lembang                                                                                                                               Rp.5000               Tidak tersedia                                                                 08.00 – 18.00 WIB
# 53                                    De Ranch                                          JL. RayaMaribaya No.17, Desa Kayuambon, Kecamatan Lembang                                                                                                                               Rp.5000                 022) 2785865  Senin – Jumat 09.00 – 17.00 WIB, Sabtu – Minggu dan Hari Libur 08.00 – 18.00 WIB
# 54                         Dusun Bambu Lembang                       JL. Kolonel Masturi Km.11, Dusun Kertawangi, Desa Cisarua, Kecamatan Lembang                                                                                                                             Rp.15.000                022) 82782020                                                                 08.00 – 21.00 WIB
# 55                         Kawah Putih Ciwidey         JL. Raya Ciwidey Patengan Km.11, Desa Lebakmuncang, Kecamatan Ciwidey, Bandung, Jawa Barat                                                                                                                             Rp.18.000                 022) 7278341                                                                 07.00 – 17.00 WIB
# 56                                 Bukit Jamur                                                                                     Tidak tersedia                                                                                                                                Gratis               Tidak tersedia                                                                            24 Jam
# 57                             Situ Patenggang                                   JL. Raya Ciwidey – Rancabali, Desa Patengan, Kecamatan Rancabali                                                                               Wisatawan Domestik Rp.15.000, Wisatawan Asing Rp.50.000               Tidak tersedia                                                                            24 Jam
# 58                                  Ranca Upas                              JL. Raya Ciwidey – Patengan Km.11, Desa Patengan, Kecamatan Rancabali                                                                                                                             Rp.10.000               0812-2345-6911                                                                            24 Jam
# 59  Ciwidey Valley Hot Spring Waterpark Resort                                     JL. Raya Barutunggul Km.17, Desa Alamenda, Kecamatan Rancabali                                                                                                                             Rp.40.000               0813-9438-0069                                                                            24 Jam

# %%
# Untuk mengetahu banyak data di tiap kategori
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Nama Tempat      60 non-null     object
#  1   Alamat           60 non-null     object
#  2   Harga/Tiket      60 non-null     object
#  3   No. Telp         60 non-null     object
#  4   Jam Operasional  60 non-null     object
# dtypes: object(5)
# memory usage: 2.5+ KB
# None

# %%
# Buang baris-baris yang memiliki data penting kosong atau "Tidak tersedia"
# Kolom yang dicek: Harga/Tiket, No. Telp, Alamat, dan Jam Operasional
df_bersih = df[
    (df["Harga/Tiket"] != "Tidak tersedia") &
    (df["No. Telp"] != "Tidak tersedia") &
    (df["Alamat"] != "Tidak tersedia") &
    (df["Jam Operasional"] != "Tidak tersedia")
]

# Reset index agar urutannya kembali dari 0 setelah baris dibuang
df_bersih = df_bersih.reset_index(drop=True)
# Tampilkan DataFrame hasil pembersihan
print(df_bersih.to_string(index=True))
# Out:
#                                    Nama Tempat                                                                                             Alamat                                                                                                                           Harga/Tiket                    No. Telp                                                                   Jam Operasional
# 0                        Curug Tilu Leuwi Opat                          Jl. Kp. Ciwangun Indah Camp, Desa Cihanjuang Rahayu, Kecamatan Parongpong                                                                                                                             Rp.10.000              0812-2224-6821                                                                 06.00 – 18.00 WIB
# 1                              Gunung Artapela                                                                 Desa Sukapura, Kecamatan Kertasari                                                                                                                              Rp.5.000              0812-2380-3013                                                                 08.00 – 17.00 WIB
# 2                     Saung Angklung Mang Udjo                    Jl. Padasuka No.116, Desa Pasirlayung, Kecamatan Cibeunying Kidul, Kota Bandung                                                                                      Senin- Jumat Rp.60.000, Sabtu – Minggu Rp.75.000                022) 7271714                                                                 09.00 – 15.30 WIB
# 3                          Ciwangun Indah Camp                      JL. Kolonel Masturi RT.03 RW.15, Desa Cihanjuang Rahayu, Kecamatan Parongpong                                                                                                                              Rp.7.000               022) 61005867                                                                 07.00 – 19.30 WIB
# 4                   Pemandian Air Panas Ciater                                   JL. Raya Ciater, Desa Nagrak, Kecamatan Ciater, Kabupaten Subang                                                                                                                  Mulai dari Rp.15.000                0260) 471700                                                                            24 Jam
# 5               Bandung Treetop Adventure Park                                    Cikole Jayagiri Resort, JL. Tangkuban Perahu Km.28, Desa Cikole                                                                                                                  Mulai dari Rp.10.000               022) 82780672                                                                 08.00 – 16.30 WIB
# 6               Terminal Wisata Grafika Cikole                                                            JL. Tangkuban Perahu Km. 8, Desa Cikole                                                                                                                                Gratis               022) 82782441                                                                 08.00 – 22.00 WIB
# 7                         NuArt Sculpture Park                                                                  JL. Setraduta Raya No.L6 Ciwaruga                                                                                                                                Gratis                022) 2025812                                                                 09.00 – 21.00 WIB
# 8                             Pine Forest Camp                JL. Maribaya Timur, Kampung Cibeunying Kaler, Desa Cibodas, Kabupaten Bandung Barat                                                                                                  Harga Paket Camping mulai Rp.150.000                022) 5204292                                                                            24 Jam
# 9                            Babakan Siliwangi                                             JL. Siliwangi No.7, Lebak Siliwangi, Kecamatan Coblong                                                                                                                              Rp.3.000                022) 2501394                                                                            24 Jam
# 10                     Kampung Batu Malakasari                                  JL. Raya Banjaran (Rencong), Desa Malakasari, Kecamatan Baleendah  Paket Wisata Pelajar Rp.90.000/Orang, Smart & Creatif Rp.110.000/Orang, Goyang Leutak Rp.85.000/Orang, Lembur Kuring Rp.95.000/Orang               022) 72591042                                                                 08.00 – 18.00 WIB
# 11                               Bukit Bintang                                                                 Desa Mekarjaya, Kecamatan Banjaran                                                                                               Hari Biasa Rp.2000, Hari Libur Rp.3.000              0819-1005-4134                                                                            24 Jam
# 12           Desa Wisata Kampung Pasir Angling                                                                Desa Sunten Jaya, Kecamatan Cibodas                                                                                                                                Gratis              0852-1886-1522                                                                            24 Jam
# 13                    Sendang Geulis Kahuripan                                                          Desa Ganjarsari, Kecamatan Cikalong Wetan                                                                                                                             Rp.10.000              0852-9544-7036                                                                 07.00 – 17.00 WIB
# 14                           Amazing Art World                                               JL. Setiabudi No.293, Desa Isola, Kecamatan Sukasari                                                                              Anak-anak Rp.80.000, Pelajar Rp.100.000, Umum Rp.150.000                022) 2025280                                                                 09.00 – 21.00 WIB
# 15                           Upside Down World                                 JL. H. Wasid No.31 (Dipatiukur), Desa Lebakgede, Kecamatan Coblong                                                                                                Anak-anak Rp.50.000, Dewasa Rp.100.000               022) 20454234                                                                 10.00 – 20.00 WIB
# 16                              Museum Geologi                               JL. Diponegoro No.57, Desa Cihaur Geulis, Kecamatan Cibeunying Kaler                                                                  Pelajara Rp.2000, Wisatawan Lokal Rp.3000, Wisatawan Asing Rp.10.000                022) 7213822                Senin – Jumat 08.00 – 16.00 WIB, Sabtu – Minggu  08.00 – 14.00 WIB
# 17                      Kebun Binatang Bandung                                  JL. Kebun Binatang No.06, Desa Lebak Siliwangi, Kecamatan Coblong                                                                                                 Anak-anak Rp.15.000, Dewasa Rp.20.000                022) 2502770                                                                 08.00 – 17.00 WIB
# 18               Taman Hutan Raya Ir.H Djuanda                 Kompleks Tahura Ir.H. Djuanda No.99, Dago Pakar, Desa Ciburial, Kecamatan Cimenyan                                                                               Wisatawan Domestik Rp.11.000, Wisatawan Manca Rp.76.000                022) 2515895                                                                 06.00 – 18.00 WIB
# 19                        Trans Studio Bandung                          JL. Jenderal Gatot Subroto No.289, Desa Cibangkong, Kecamatan Batununggal                                                                    Senin – Jumat Rp.150.000, Sabtu – Minggu dan Hari Libur Rp.250.000  022) 86012555 087821054789  Senin – Jumat 10.00 – 19.00 WIB, Sabtu – Minggu dan Hari Libur 09.00 – 21.00 WIB
# 20                             Floating Market                                                          JL. Grand Hotel No.33E, Kecamatan Lembang                                                                                                                             Rp.15.000                022) 2787766                Senin – Kamis 09.00 – 19.00 WIB, Jum’at – Minggu 09.00 – 20.00 WIB
# 21                   Taman Miniatur Kereta Api                                                          JL. Grand Hotel No.33E, Kecamatan Lembang                                                                                                                             Rp.25.000                022) 2787766                Senin – Kamis 09.00 – 19.00 WIB, Jum’at – Minggu 09.00 – 20.00 WIB
# 22                        Jendela Alam Lembang  Komplek Graha Puspa, JL. Sersan Bajuri Km.45, Dusun Cihideung, Desa Parongpong, Kecamatan Lembang                                                                                                                             Rp.15.000                022) 2788482                                                                 09.00 – 16.00 WIB
# 23                    Kampung Gajah Wonderland                       JL. Sersan Bajuri Km.38, Dusun Cihideung, Desa Parongpong, Kecamatan Lembang                                                                      Senin – Kamis Rp.10.000, Jumat – Minggu dan hari Libur Rp.20.000               022) 88884012                                                                 08.00 – 17.00 WIB
# 24                       Observatorium Bosscha                                                          JL. Peneropong Bintang, Kecamatan Lembang                                                                                                                   Mulai dari Rp.7.500                022) 2786001                                                                 09.00 – 13.00 WIB
# 25                                 GunungPutri                                                 JL. Gunung Putri, Desa Jayagiri, Kecamatan Lembang                                                                                                                   Mulai dari Rp.5.000              0852-1886-1522                                                                 08.00 – 17.00 WIB
# 26                               Taman Begonia                                          JL. Raya Maribaya No.120A, Desa Cibogo, Kecamatan Lembang                                                                                                                             Rp.10.000                022) 2788527                                                                 08.00 – 17.30 WIB
# 27                         Taman Lembah Dewata                                         JL. Tangkuban Perahu Km.37, Desa Cibogo, Kecamatan Lembang                                                                                                                             Rp.10.000              0812-2253-6000                                                                 08.00 – 17.00 WIB
# 28                             Balitsa Lembang                                                     JL. Tangkuban Perahu No.517, Kecamatan Lembang                                                                                                                                Gratis               022) 22786025                                                                 08.00 – 17.00 WIB
# 29                                    De Ranch                                          JL. RayaMaribaya No.17, Desa Kayuambon, Kecamatan Lembang                                                                                                                               Rp.5000                022) 2785865  Senin – Jumat 09.00 – 17.00 WIB, Sabtu – Minggu dan Hari Libur 08.00 – 18.00 WIB
# 30                         Dusun Bambu Lembang                       JL. Kolonel Masturi Km.11, Dusun Kertawangi, Desa Cisarua, Kecamatan Lembang                                                                                                                             Rp.15.000               022) 82782020                                                                 08.00 – 21.00 WIB
# 31                         Kawah Putih Ciwidey         JL. Raya Ciwidey Patengan Km.11, Desa Lebakmuncang, Kecamatan Ciwidey, Bandung, Jawa Barat                                                                                                                             Rp.18.000                022) 7278341                                                                 07.00 – 17.00 WIB
# 32                                  Ranca Upas                              JL. Raya Ciwidey – Patengan Km.11, Desa Patengan, Kecamatan Rancabali                                                                                                                             Rp.10.000              0812-2345-6911                                                                            24 Jam
# 33  Ciwidey Valley Hot Spring Waterpark Resort                                     JL. Raya Barutunggul Km.17, Desa Alamenda, Kecamatan Rancabali                                                                                                                             Rp.40.000              0813-9438-0069                                                                            24 Jam

# %% [markdown]
# # Pengolahan Data
# ## Pengelompokkan Tarif

# %%
# Definisikan fungsi untuk mengategorikan tarif berdasarkan isi kolom Harga/Tiket
def kategorikan_tarif(harga):
    # Cek jika datanya kosong atau NaN
    if pd.isna(harga):
        return "Tidak diketahui"

    # Ubah ke huruf kecil untuk memudahkan pencarian kata "gratis"
    harga = str(harga).lower()
    if "gratis" in harga:
        return "Gratis"

    # Ambil semua angka dari string (mengabaikan titik pemisah ribuan)
    angka_list = re.findall(r"\d+", harga.replace(".", ""))
    angka_list = [int(a) for a in angka_list if a.isdigit()]

    # Jika ditemukan angka, ambil harga minimum dan kategorikan
    if angka_list:
        min_harga = min(angka_list)
        if min_harga <= 15000:
            return "Murah"
        elif min_harga <= 30000:
            return "Menengah"
        else:
            return "Mahal"
    else:
        return "Tidak diketahui"

# Terapkan fungsi ke setiap baris kolom Harga/Tiket
df_bersih["Kategori Tarif"] = df_bersih["Harga/Tiket"].apply(kategorikan_tarif)

# Tampilkan jumlah tempat wisata per kategori tarif
print("Jumlah Wisata per Kategori Tarif:")
print(df_bersih["Kategori Tarif"].value_counts())
# Out:
# Jumlah Wisata per Kategori Tarif:
# Kategori Tarif
# Murah       21
# Mahal        7
# Gratis       4
# Menengah     2
# Name: count, dtype: int64

# %%
# Import library matplotlib untuk visualisasi data
import matplotlib.pyplot as plt

# Hitung jumlah tempat wisata per kategori tarif
tarif_counts = df_bersih["Kategori Tarif"].value_counts()

# Buat diagram batang dari hasil value_counts
plt.figure(figsize=(8, 5))  # Atur ukuran gambar
tarif_counts.plot(kind="bar", color=["green", "blue", "orange", "red"])  # Jenis diagram & warna batang

# Judul dan label sumbu
plt.title("Jumlah Tempat Wisata per Kategori Tarif")
plt.xlabel("Kategori Tarif")
plt.ylabel("Jumlah Tempat Wisata")

# Atur tampilan sumbu X dan garis bantu di sumbu Y
plt.xticks(rotation=0)  # Teks horizontal
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Tampilkan plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # Pengolahan Data
# ## Pengelompokkan Wilayah

# %%
# Import pustaka visualisasi
import matplotlib.pyplot as plt

# Menghitung 10 wilayah teratas berdasarkan jumlah tempat wisata (dari kolom 'Alamat')
wilayah_counts = df_bersih["Alamat"].value_counts().head(10)

# Membuat diagram batang horizontal
plt.figure(figsize=(8, 5))  # Mengatur ukuran gambar
wilayah_counts.plot(kind="barh", color="skyblue")  # Menampilkan grafik batang horizontal

# Menambahkan judul dan label sumbu
plt.title("10 Wilayah dengan Jumlah Tempat Wisata Terbanyak")
plt.xlabel("Jumlah Tempat Wisata")

# Membalik urutan sumbu Y agar peringkat tertinggi berada di atas
plt.gca().invert_yaxis()

# Mengatur tata letak agar elemen tidak terpotong
plt.tight_layout()

# Menampilkan visualisasi
plt.show()

# %%
# Fungsi untuk mengekstrak nama wilayah (kecamatan, desa, kota, atau kabupaten) dari kolom 'Alamat'
def ekstrak_wilayah(alamat):
    if pd.isna(alamat):
        return "Lainnya"  # Jika data kosong, kembalikan "Lainnya"

    alamat = alamat.strip()  # Hilangkan spasi di awal/akhir

    # Deteksi pola umum yang sering muncul di alamat
    kec = re.search(r"Kecamatan ([\w\s]+)", alamat, re.I)
    if kec:
        return kec.group(1).strip()

    desa = re.search(r"Desa ([\w\s]+)", alamat, re.I)
    if desa:
        return desa.group(1).strip()

    kota = re.search(r"Kota ([\w\s]+)", alamat, re.I)
    if kota:
        return kota.group(1).strip()

    kab = re.search(r"Kabupaten ([\w\s]+)", alamat, re.I)
    if kab:
        return kab.group(1).strip()

    # Jika tidak ditemukan pola umum, ambil kata terakhir yang berupa huruf (bukan angka/simbol)
    kata = re.findall(r"[a-zA-Z]+", alamat)
    if kata:
        return kata[-1].strip().title()

    return "Lainnya"  # Jika tidak ditemukan apapun

# Menerapkan fungsi ke kolom 'Alamat' dan membuat kolom baru bernama 'Wilayah'
df_bersih["Wilayah"] = df_bersih["Alamat"].apply(ekstrak_wilayah)

# Menampilkan jumlah tempat wisata per wilayah
print(df_bersih["Wilayah"].value_counts())
# Out:
# Wilayah
# Lembang             11
# Coblong              3
# Rancabali            2
# Parongpong           2
# Cibodas              2
# Cikole               2
# Kertasari            1
# Ciater               1
# Ciwaruga             1
# Cibeunying Kidul     1
# Banjaran             1
# Baleendah            1
# Cikalong Wetan       1
# Sukasari             1
# Cimenyan             1
# Cibeunying Kaler     1
# Batununggal          1
# Ciwidey              1
# Name: count, dtype: int64

# %%
# Import pustaka visualisasi
import matplotlib.pyplot as plt

# Menghitung 10 wilayah dengan jumlah tempat wisata terbanyak
wilayah_counts = df_bersih["Wilayah"].value_counts().head(10)

# Membuat diagram batang vertikal
plt.figure(figsize=(8, 5))  # Menentukan ukuran gambar
wilayah_counts.plot(kind="bar", color="lightgreen")  # Menampilkan diagram batang dengan warna hijau muda

# Menambahkan judul dan label sumbu
plt.title("Distribusi Tempat Wisata per Wilayah")
plt.ylabel("Jumlah Tempat Wisata")
plt.xlabel("Wilayah")

# Mengatur rotasi label pada sumbu X untuk meningkatkan keterbacaan
plt.xticks(rotation=45)

# Merapikan tata letak agar elemen tidak terpotong
plt.tight_layout()

# Menampilkan grafik
plt.show()

# %% [markdown]
# # Pengolahan Data
# ## Pengelompokkan Jam Operasional

# %%
# Fungsi untuk menguraikan format jam operasional campuran menjadi jadwal harian per hari
def parse_operasional_campuran(op):
    # Normalisasi nama hari yang ditulis tidak konsisten
    hari_alias = {"Jum'at": "Jumat", "Jum’at": "Jumat", "JUMAT": "Jumat"}
    hari_lengkap = ["Senin", "Selasa", "Rabu", "Kamis", "Jumat", "Sabtu", "Minggu"]
    jadwal = {h: "-" for h in hari_lengkap}  # Default: semua hari kosong

    if not isinstance(op, str):  # Jika bukan string, kembalikan default
        return jadwal

    # Normalisasi simbol dan kata-kata umum
    op = op.replace("–", "-")  # Ganti dash panjang dengan "-"
    op = op.replace("’", "'").replace("‘", "'")  # Normalisasi kutipan
    op = re.sub(r"dan Hari Libur", "", op, flags=re.I)  # Hapus keterangan tambahan

    # Jika format berlaku untuk semua hari (misal "24 Jam", "Tutup", atau rentang jam langsung)
    if re.fullmatch(r"(24\s*Jam|Tutup|[\d.]+\s*-\s*[\d.]+.*)", op.strip()):
        return {h: op.strip() for h in hari_lengkap}

    # Pisahkan bagian-bagian berdasarkan koma
    bagian = [b.strip() for b in re.split(r",\s*", op)]

    for b in bagian:
        # Tangkap pola seperti: "Senin-Jumat 08.00-17.00"
        m = re.match(r"(.+?)\s+(\d{2}\.\d{2}\s*-\s*\d{2}\.\d{2})", b)
        if not m:
            continue
        rentang_hari, jam = m.groups()

        # Normalisasi rentang hari
        rentang_hari = rentang_hari.replace("–", "-").replace("’", "'").strip()
        rentang_hari = " ".join([hari_alias.get(word, word) for word in rentang_hari.split()])

        # Penanganan rentang hari (misal: Senin - Jumat)
        if "-" in rentang_hari:
            awal, akhir = [x.strip() for x in rentang_hari.split("-")]
            try:
                idx1 = hari_lengkap.index(awal)
                idx2 = hari_lengkap.index(akhir)
                for h in hari_lengkap[idx1:idx2+1]:
                    jadwal[h] = jam
            except:
                continue
        else:
            # Penanganan hari tunggal
            for h in hari_lengkap:
                if h in rentang_hari:
                    jadwal[h] = jam

    return jadwal

# Ganti nama kolom "Wilayah" menjadi "Tempat" agar lebih sesuai konteks
df_bersih = df_bersih.rename(columns={"Wilayah": "Tempat"})

# Terapkan fungsi parsing jam operasional dan ubah hasil dict menjadi kolom per hari
df_jadwal = df_bersih["Jam Operasional"].apply(parse_operasional_campuran).apply(pd.Series)

# Gabungkan dengan nama tempat agar informasi tetap terhubung
df_final = pd.concat([df_bersih[["Tempat"]], df_jadwal], axis=1)

# Tampilkan hasil akhir
print(df_final.to_string(index=True))
# Out:
#               Tempat              Senin             Selasa               Rabu              Kamis              Jumat              Sabtu             Minggu
# 0         Parongpong  06.00 - 18.00 WIB  06.00 - 18.00 WIB  06.00 - 18.00 WIB  06.00 - 18.00 WIB  06.00 - 18.00 WIB  06.00 - 18.00 WIB  06.00 - 18.00 WIB
# 1          Kertasari  08.00 - 17.00 WIB  08.00 - 17.00 WIB  08.00 - 17.00 WIB  08.00 - 17.00 WIB  08.00 - 17.00 WIB  08.00 - 17.00 WIB  08.00 - 17.00 WIB
# 2   Cibeunying Kidul  09.00 - 15.30 WIB  09.00 - 15.30 WIB  09.00 - 15.30 WIB  09.00 - 15.30 WIB  09.00 - 15.30 WIB  09.00 - 15.30 WIB  09.00 - 15.30 WIB
# 3         Parongpong  07.00 - 19.30 WIB  07.00 - 19.30 WIB  07.00 - 19.30 WIB  07.00 - 19.30 WIB  07.00 - 19.30 WIB  07.00 - 19.30 WIB  07.00 - 19.30 WIB
# 4             Ciater             24 Jam             24 Jam             24 Jam             24 Jam             24 Jam             24 Jam             24 Jam
# 5             Cikole  08.00 - 16.30 WIB  08.00 - 16.30 WIB  08.00 - 16.30 WIB  08.00 - 16.30 WIB  08.00 - 16.30 WIB  08.00 - 16.30 WIB  08.00 - 16.30 WIB
# 6             Cikole  08.00 - 22.00 WIB  08.00 - 22.00 WIB  08.00 - 22.00 WIB  08.00 - 22.00 WIB  08.00 - 22.00 WIB  08.00 - 22.00 WIB  08.00 - 22.00 WIB
# 7           Ciwaruga  09.00 - 21.00 WIB  09.00 - 21.00 WIB  09.00 - 21.00 WIB  09.00 - 21.00 WIB  09.00 - 21.00 WIB  09.00 - 21.00 WIB  09.00 - 21.00 WIB
# 8            Cibodas             24 Jam             24 Jam             24 Jam             24 Jam             24 Jam             24 Jam             24 Jam
# 9            Coblong             24 Jam             24 Jam             24 Jam             24 Jam             24 Jam             24 Jam             24 Jam
# 10         Baleendah  08.00 - 18.00 WIB  08.00 - 18.00 WIB  08.00 - 18.00 WIB  08.00 - 18.00 WIB  08.00 - 18.00 WIB  08.00 - 18.00 WIB  08.00 - 18.00 WIB
# 11          Banjaran             24 Jam             24 Jam             24 Jam             24 Jam             24 Jam             24 Jam             24 Jam
# 12           Cibodas             24 Jam             24 Jam             24 Jam             24 Jam             24 Jam             24 Jam             24 Jam
# 13    Cikalong Wetan  07.00 - 17.00 WIB  07.00 - 17.00 WIB  07.00 - 17.00 WIB  07.00 - 17.00 WIB  07.00 - 17.00 WIB  07.00 - 17.00 WIB  07.00 - 17.00 WIB
# 14          Sukasari  09.00 - 21.00 WIB  09.00 - 21.00 WIB  09.00 - 21.00 WIB  09.00 - 21.00 WIB  09.00 - 21.00 WIB  09.00 - 21.00 WIB  09.00 - 21.00 WIB
# 15           Coblong  10.00 - 20.00 WIB  10.00 - 20.00 WIB  10.00 - 20.00 WIB  10.00 - 20.00 WIB  10.00 - 20.00 WIB  10.00 - 20.00 WIB  10.00 - 20.00 WIB
# 16  Cibeunying Kaler      08.00 - 16.00      08.00 - 16.00      08.00 - 16.00      08.00 - 16.00      08.00 - 16.00      08.00 - 14.00      08.00 - 14.00
# 17           Coblong  08.00 - 17.00 WIB  08.00 - 17.00 WIB  08.00 - 17.00 WIB  08.00 - 17.00 WIB  08.00 - 17.00 WIB  08.00 - 17.00 WIB  08.00 - 17.00 WIB
# 18          Cimenyan  06.00 - 18.00 WIB  06.00 - 18.00 WIB  06.00 - 18.00 WIB  06.00 - 18.00 WIB  06.00 - 18.00 WIB  06.00 - 18.00 WIB  06.00 - 18.00 WIB
# 19       Batununggal      10.00 - 19.00      10.00 - 19.00      10.00 - 19.00      10.00 - 19.00      10.00 - 19.00      09.00 - 21.00      09.00 - 21.00
# 20           Lembang      09.00 - 19.00      09.00 - 19.00      09.00 - 19.00      09.00 - 19.00      09.00 - 20.00      09.00 - 20.00      09.00 - 20.00
# 21           Lembang      09.00 - 19.00      09.00 - 19.00      09.00 - 19.00      09.00 - 19.00      09.00 - 20.00      09.00 - 20.00      09.00 - 20.00
# 22           Lembang  09.00 - 16.00 WIB  09.00 - 16.00 WIB  09.00 - 16.00 WIB  09.00 - 16.00 WIB  09.00 - 16.00 WIB  09.00 - 16.00 WIB  09.00 - 16.00 WIB
# 23           Lembang  08.00 - 17.00 WIB  08.00 - 17.00 WIB  08.00 - 17.00 WIB  08.00 - 17.00 WIB  08.00 - 17.00 WIB  08.00 - 17.00 WIB  08.00 - 17.00 WIB
# 24           Lembang  09.00 - 13.00 WIB  09.00 - 13.00 WIB  09.00 - 13.00 WIB  09.00 - 13.00 WIB  09.00 - 13.00 WIB  09.00 - 13.00 WIB  09.00 - 13.00 WIB
# 25           Lembang  08.00 - 17.00 WIB  08.00 - 17.00 WIB  08.00 - 17.00 WIB  08.00 - 17.00 WIB  08.00 - 17.00 WIB  08.00 - 17.00 WIB  08.00 - 17.00 WIB
# 26           Lembang  08.00 - 17.30 WIB  08.00 - 17.30 WIB  08.00 - 17.30 WIB  08.00 - 17.30 WIB  08.00 - 17.30 WIB  08.00 - 17.30 WIB  08.00 - 17.30 WIB
# 27           Lembang  08.00 - 17.00 WIB  08.00 - 17.00 WIB  08.00 - 17.00 WIB  08.00 - 17.00 WIB  08.00 - 17.00 WIB  08.00 - 17.00 WIB  08.00 - 17.00 WIB
# 28           Lembang  08.00 - 17.00 WIB  08.00 - 17.00 WIB  08.00 - 17.00 WIB  08.00 - 17.00 WIB  08.00 - 17.00 WIB  08.00 - 17.00 WIB  08.00 - 17.00 WIB
# 29           Lembang      09.00 - 17.00      09.00 - 17.00      09.00 - 17.00      09.00 - 17.00      09.00 - 17.00      08.00 - 18.00      08.00 - 18.00
# 30           Lembang  08.00 - 21.00 WIB  08.00 - 21.00 WIB  08.00 - 21.00 WIB  08.00 - 21.00 WIB  08.00 - 21.00 WIB  08.00 - 21.00 WIB  08.00 - 21.00 WIB
# 31           Ciwidey  07.00 - 17.00 WIB  07.00 - 17.00 WIB  07.00 - 17.00 WIB  07.00 - 17.00 WIB  07.00 - 17.00 WIB  07.00 - 17.00 WIB  07.00 - 17.00 WIB
# 32         Rancabali             24 Jam             24 Jam             24 Jam             24 Jam             24 Jam             24 Jam             24 Jam
# 33         Rancabali             24 Jam             24 Jam             24 Jam             24 Jam             24 Jam             24 Jam             24 Jam

# %%
# Langkah 1: Salin DataFrame df_final untuk pengolahan durasi, guna menjaga data asli tetap aman
df_durasi = df_final.copy()

# Langkah 2: Tambahkan kembali kolom "Nama Tempat" dari df_bersih agar label visualisasi lebih informatif
df_durasi["Nama Tempat"] = df_bersih["Nama Tempat"]

# Langkah 3: Definisikan fungsi untuk menghitung durasi jam buka (dalam satuan jam)
def hitung_durasi(jam_str):
    if pd.isna(jam_str) or "Tutup" in jam_str or "Jam" in jam_str:
        return 24 if "24" in str(jam_str) else 0  # 24 jam jika disebut "24", selain itu diasumsikan tutup
    jam_str = jam_str.replace("WIB", "").strip()
    try:
        awal, akhir = [datetime.strptime(j.strip(), "%H.%M") for j in jam_str.split(" - ")]
        durasi = (akhir - awal).seconds / 3600  # Hitung selisih waktu dalam jam
        return durasi
    except:
        return 0  # Jika format tidak dikenali, kembalikan 0

# Langkah 4: Ubah seluruh kolom hari menjadi durasi jam buka
hari_list = ["Senin", "Selasa", "Rabu", "Kamis", "Jumat", "Sabtu", "Minggu"]
for hari in hari_list:
    df_durasi[hari] = df_durasi[hari].apply(hitung_durasi)

# Langkah 5: Visualisasi durasi jam buka untuk setiap hari secara terpisah
for hari in hari_list:
    plt.figure(figsize=(14, 6))
    data = df_durasi.sort_values(by=hari, ascending=False)

    plt.bar(data["Nama Tempat"], data[hari], color='orange')  # Diagram batang
    plt.title(f"Durasi Buka Tempat Wisata pada Hari {hari}", fontsize=14)
    plt.xlabel("Nama Tempat Wisata")
    plt.ylabel("Durasi Buka (jam)")
    plt.xticks(rotation=90, fontsize=8)  # Rotasi label x agar terbaca
    plt.ylim(0, 25)  # Rentang y maksimal 24 jam
    plt.grid(axis='y', linestyle='--', alpha=0.3)  # Garis bantu horizontal
    plt.tight_layout()
    plt.show()

# %%
# Set "Nama Tempat" sebagai index dan ambil kolom hari
df_heat = df_durasi.set_index("Nama Tempat")[hari_list]

# Buat figure dengan ukuran yang disesuaikan dengan jumlah tempat
plt.figure(figsize=(14, len(df_heat) * 0.4))

# Plot heatmap dari durasi buka tiap tempat per hari
sns.heatmap(
    df_heat,
    annot=True,                # Tampilkan nilai pada tiap sel
    fmt=".1f",                 # Format angka desimal
    cmap="YlGnBu",             # Skema warna hijau ke biru
    linewidths=0.5,            # Jarak antar sel
    cbar_kws={'label': 'Durasi (jam)'}  # Label untuk color bar
)

# Tambahkan judul dan label sumbu
plt.title("Heatmap Durasi Buka Tempat Wisata per Hari", fontsize=14)
plt.xlabel("Hari")
plt.ylabel("Nama Tempat")

# Atur layout agar elemen tidak saling tumpang tindih
plt.tight_layout()

# Tampilkan visualisasi heatmap
plt.show()

# %% [markdown]
# #Deskripsi
# ## Jenis Wisata

# %%
# Fungsi untuk mengambil nama tempat dan deskripsi dari sebuah URL
def ambil_nama_dan_deskripsi(url):
    res = requests.get(url)
    soup = BeautifulSoup(res.text, "html.parser")

    # Ambil konten utama dari halaman
    konten = soup.find("div", class_="entry-content")
    data = []

    if konten:
        # Cari semua tag <h3> di dalam konten (biasanya berisi judul tempat)
        h3_tags = konten.find_all("h3")
        for tag in h3_tags:
            title = tag.get_text(strip=True)

            # Filter judul yang dimulai dengan angka (misal: "1. Tempat A")
            if any(char.isdigit() for char in title[:4]):
                # Bersihkan nama tempat dari angka dan simbol
                nama = re.sub(r"^\d+\.\s*", "", title).replace("❤️", "").strip()

                # Ambil deskripsi dari tag-tag berikutnya sampai ketemu <h3> baru
                deskripsi = ""
                next_tag = tag.next_sibling
                while next_tag:
                    if isinstance(next_tag, str):
                        next_tag = next_tag.next_sibling
                        continue
                    if next_tag.name == "h3":
                        break
                    if next_tag.name == "p":
                        teks = next_tag.get_text(strip=True)
                        # Hapus paragraf yang mengandung info teknis seperti alamat, tarif, dll
                        if not any(k in teks.lower() for k in ["alamat", "klik disini", "koordinat", "tarif", "htm", "jam"]):
                            deskripsi += teks + " "
                    next_tag = next_tag.next_sibling

                # Simpan jika deskripsi tidak kosong
                if deskripsi.strip():
                    data.append((nama, deskripsi.strip()))
                else:
                    print(f"[SKIPPED] {nama}")

    return data

# Proses scraping dari semua URL
semua_data = []
for url in urls:
    hasil = ambil_nama_dan_deskripsi(url)
    semua_data.extend(hasil)

# Buat DataFrame dari hasil scraping
df_deskripsi = pd.DataFrame(semua_data, columns=["Nama Tempat", "Deskripsi"])
df_deskripsi.index += 1  # Mulai index dari 1 agar lebih rapi

# Tampilkan hasil akhir
print(df_deskripsi.to_string(index=True))
# Out:
#                                    Nama Tempat                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Deskripsi
# 1                        Curug Tilu Leuwi Opat                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Dinamakan Curug Tilu (Tiga), karena air terjun ini memiliki 3 tingkatan. Curug pertama adalah Curug Tilu Leuwi Opat dengan ketinggian sekitar 3 meter dan menjadi suguhan utama wisata ini karena di dekatnya terdapat Camping Ground Ciwangun Indah Camp. Sesuatu yang unik dan menarik untuk dilihat dari air terjun ini adalah adanya asap yang unik yang berasal dari cipratan air terjun. Sayang sekali kolam di dasar air terjun cukup berisiko jika digunakan untuk aktifitas berenang karena kedalamannya sekitar 15 meter. Curug kedua dinamakan Curug Kecapi yang tidak terlalu tinggi dan debit airnya juga kecil namun sangat jernih. Sedang curug ketiga dikenal dengan nama Curug Sawer.
# 2                                 Curug Malela                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Besar dan mempesona, gambaran itulah yang pantas untuk melukiskan Curug Malela pada saat debit air sedang besar dan aliran air yang melintasi air terjun ini sedang deras. Karena Curug Malela yang memiliki 5 jalur air terjun ini memang berketinggian 60 meter dengan lebar sekitar 70 meter. Kemegahan dan keindahan air terjun ini, bila dilihat dari kejauhan menyerupai benang-benang sutra yang halus dan berkilauan.
# 3                              Gunung Artapela                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Eksotisme pemandangan alam dengan hamparan hijau rerumputan dan pepohonan yang berselimut kabut menjadi daya tarik utama bagi para pendaki yang berpetualang di gunung yang sudah tidak aktif ini. Terlebih pada saat matahari sedang terbit atau akan tenggelam, sunrise dan sunset yang disuguhkan keindahannya sulit untuk dilukiskan dengan kata-kata. Di puncak gunung yang memiliki ketinggian 2.194 meter dpl ini juga dapat dijumpai padang rumput dan ilalang seluas 40 hektar yang menyajikan pemandangan khas dan tidak dijumpai di tempat lain. Tidak hanya itu, tepat di bawah puncak Artapela Pengalengan, pendaki juga dapat menjumpai danau alam yang menawan yang dikenal dengan nama Danau Aul.
# 4                                  Gunung Nini                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Keindahan sunrise dan sunset hanya salah satu dari pesona yang disuguhkan oleh Gunung Nini atau Bukit Nini yang memiliki ketinggian 1.600 meter dpl dan berada di kawasan Bandung Selatan ini. Keindahan lainnya akan dijumpai saat sudah sampai di atas bukit. Karena di tempat ini terdapat sebuah saung yang fungsinya sama dengan Gardu Pandang, yakni untuk menikmati keindahan alam sekitar dari atas ketinggian. Dengan dikelilingi perkebunan teh seluas 2.022 hektar, membuat pendaki yang sudah mencapai saung di atas bukit akan dapat merasakan sensasi tersendiri saat melihat hamparan hijau yang mengelilingi bukit.
# 5                     Saung Angklung Mang Udjo                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Saung Angklung Mang Udjo selain menjadi destinasi wisata budaya dan edukasi juga merupakan satu-satunya Pusat Kesenian Tradidional Angklung. Pertunjukan yang dimainkan oleh anak-anak bahkan sebagian besar berumur kurang dari 10 tahun tersebut meliputi permainan musik angklung, Arumba yakni tarian tradisional Sunda yang diiringi musik angklung, wayang golek, tari Jaipong dan Helaran yakni ritual syukuran yang menjadi tradisi masyarakat Sunda. Di lokasi Saung Angklung Mang Udjo juga terdapat toko souvenir yang menjual berbagai macam kerajinan tangan dalam bentuk wayang golek, gantungan kunci, sandal, tas dan berbagai macam souvenir lainnya, termasuk alat-alat musik angklung. Jika ingin menikmati lebih lama suasana wisata budaya yang ada di tempat ini, tersedia pula Guest House yang dapat disewa dengan harga Rp.300.000 – Rp.900.000 permalam.
# 6                                 Situ Cisanti                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Danau dengan air yang jernih menjadi suguhan utama bagi wisatawan yang berkunjung ke sini. Selain itu, keindahan panorama alam di area seluas hampir 10 hektar tersebut juga bakal memanjakan mata siapapun. Karena lokasi wisata yang dipenuhi pepohonan ini dikelilingi dengan gunung-gunung yang menjulang tinggi, yaitu Gunung Wayang, Gunung Malabar, Gunung Rakutak, Gunung Kendang dan Gunung Bedil. Perpaduan hijaunya pepohonan dengan latar belakang pegunungan itulah yang menciptakan pemandangan alam yang sangat indah.
# 7                        Bukit Gantole Cililin                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Dinamakan Bukit Gantole karena di bukit yang memiliki ketinggian 392 meter dpl ini dulu pernah dipakai sebagai venue cabang olah raga Gantole pada penyelenggaraan PON XIX Jawa Barat. Untuk mencapai lokasi, pengunjung harus berjalan sekitar 5 km dari desa Tanjungjaya dengan jalan menanjak yang memiliki kemiringan hingga 45 derajat. Sehingga bagi mereka yang memiliki hobby tracking menyusuri medan-medan berat dan menembus rimbun pepohonan, perjalanan menuju Bukit Gantole bakal menjadi perjalanan yang sangat menyenangkan. Meski fasilitas yang ada di puncak bukit sangat minim, namun pengunjung akan terpuaskan dengan keindahan pemandangan di sebelah utara bukit berupa tempat-tempat wisata yang ada di Cimahi, di kawasan Lembang dan tempat wisata yang ada di Dago saat dilihat dari ketinggian. Termasuk juga hamparan persawahan, perkampungan penduduk, hamparan air waduk Saguling serta Gunung Malabar yang tampak eksotis saat dilihat dari kejauhan.
# 8                                 Curug Cimahi                                                                                                                                                                                                                                                                                                                                                                                                                Air terjun yang berada di ketinggian 1.050 meter dpl ini berbeda dengan wisata air terjun pada umumnya yang ada di Indonesia, karena pihak Perhutani KPH Bandung Utara selaku pengelola tempat wisata ini telah memasukkan unsur pencahayaan dengan mengadopsi salah satu wisata air terjun yang ada di Amerika tepatnya di negara bagian Colorado. Dengan memasukkan unsur pencahayaan yakni memasang lampu berwarna-warni di bagian belakang air terjun, membuat air yang jatuh dari ketinggian 71 meter, sebelum sampai di dasar air terjun menebarkan kilauan warna-warni menyerupai pelangi, sehingga tampak semakin indah. Kawasan Curug Cimahi yang juga menjadi habitat kera ini benar-benar dikelola secara profesional, sehingga tidak sulit bagi para wisatawan memperoleh spot yang cantik untuk dibidik dengan lensa kamera. Selain itu beberapa fasailitas juga telah disiapkan, seperti pagar pengaman, bangku-bangku untuk beristirahat, Pusat Informasi dan Pos Jaga, Shelter, Mushollah, Piknik Site, lahan parkir dan berbagai fasilitas untuk membuat para wisatawan merasa aman dan nyaman. Selanjutnya…
# 9                                Situ Cileunca                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Berada di ketinggian 1.500 meter dpl dan dikelilingi perkebunan teh membuat keindahan alam yang dihadirkan Situ Cileunca berpadu dengan sejuk dan segarnya udara. Terlebih lokasi wisata ini juga diapit oleh tebing dan pegunungan yaitu Papandayan, Sepuh dan Malabar. Situ Cileunca sendiri sebenarnya merupakan waduk PLTA (Pusat Listrik Tenaga Air) yang menampung air dari Sungai Palayangan yang selama ini dikenal sebagai tempat untuk beraktifitas arung jeram. Dengan area waduk seluas 1.400 hektar, berbagai aktifitas wisatapun menyertai tempat ini, seperti berkemah di Camping Ground yang telah tersedia, menyusuri permukaan danau dan memancing dengan menyewa perahu nelayan, mengunjungi kebun strawberry di sekitar lokasi wisata, dan memompa adrenalin lewat aktifitas arung jeram.
# 10                         Ciwangun Indah Camp                                                                                                                                                                                                                                                                                                                                                               Bagi para pecinta wisata outbond, Ciwangun Indah Camp (CIC) bakal memberi kepuasan, karena  selain lokasinya berada di tengah kawasan Wisata Lembang yang dipenuhi pepohonan besar dan berbagai jenis tanaman bunga yang indah, tempat ini juga menyediakan berbagai jenis kegiatan wisata alam, mulai dari hiking, Fun Games, Camping Ground, Team Building hingga Company Gathering. CIC sendiri sebenarnya merupakan Desa Wisata dengan luas sekitar 22 hektar. Dengan kontur daerah berupa lembah dan perbukitan membuat tempat ini penuh denganspotyang indah. Sehingga selain melatih fisik lewat aktifitas outbond, pengunjung yang datang ke sini juga dapat menikmati keindahan hutan pinus, kebun teh, sungai Situ Lembang, lembah-lembah, danau buatan, serta mengunjungi kebun strawberry. Sedang berbagai fasilitas yang disediakan bagi para pengunjung, diantaranya adalah: Camping Ground, Area Outbond, 3 buah saung yang masing-masing dapat menampung 100 orang, gazebo di beberapa titik peristirahatan, Saung Makan yang menyediakan berbagai macam menu khas Jawa Barat dan makanan Nusantara lainnya, Masjid, Aula, Villa serta lahan parkir yang luas.
# 11                  Pemandian Air Panas Ciater                                                                                                                                                                                                                                                                                                                                                                                                                      Sumber air panas yang mulai dikembangkan oleh pemerintah sejak tahun 1968 ini tidak hanya dikenal oleh para wisatawan dari dalam negeri tapi juga turis mancanegara. Karena itu pula di lokasi pemandian  disiapkan sejumlah fasilitas seperti Ciater Spa Resort, Spa and Restaurant, Gracia Spa Resort Hotel, dan Puspa Sari Hotel. Berbagai macam wahana juga melengkapi Pemandian Air Panas Ciater, mulai dari wahana permainan anak, fasilitas olah raga, Camping Ground, Outbond Area, Kolam Pemancingan, serta Ruang Konferensi yang memiliki Ruang Makan yang luas. Sumber air panas yang mengalir di Ciater berasal dari Gunung Tangkuban Perahu yang mengairi wilayah seluas 30 hektar, sehingga pemanfaatannya tidak hanya untuk pemandian saja, tapi juga untuk irigasi sawah. Khusus untuk air panas yang dimanfaatkan sebagai  pemandian, temperaturnya sekitar 37 – 42 derajat Celcius. Kolam pemandian tersebut memiliki berbagai macam jenis dan berbagai macam harga. Ada kolam sederhana yang hanya bisa dipakai untuk berendam, ada juga kolam dengan ukuran luas yang dapat dipakai untuk berenang.
# 12                          Puncak Ciumbuleuit                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Berada di kawasan pegunungan berdataran tinggi dengan jarak sekitar 7 km dari kota Bandung, Puncak Ciumbuleuit yang populer dengan sebutan Punclut ada diketinggian 1000 meter dpl. Dengan lokasi yang ada di atas ketinggian itulah membuat udara di kawasan ini terasa sejuk pada siang hari dan sangat dingin pada malam hari. Punclut yang menempati areal seluas 290 hektar memiliki daya tarik tersendiri sebagai objek wisata, karena dari tempat ini, landskap kota bandung yang eksotis berpagar Gunung Malabar dan Gunung Patuha dapat dilihat secara utuh, termasuk beberapa landmark yang ada di kota Bandung seperti Menara Kembar Masjid Raya Jawa Barat, Jembatan Layang Surapati, dan alun-alun kota Bandung.
# 13              Bandung Treetop Adventure Park                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             “Fun, Adventure and Adrenalin” tema itulah yang diusung Bandung Treetop Adventure Park yang merupakan salah satu dari 350 cabang Treetop Adventure Park yang tersebar di berbagai penjuru dunia. Para pengunjung yang datang ke sini akan disuguhi dengan berbagai macam wahana permainan yang memacu adrenalin sehingga butuh nyali yang besar. Untuk dapat bermain di tempat wisata petualangan ini, biaya yang harus dikeluarkan ada 2 kategori, yaitu: untuk turis lokal Rp. 180.000 (Dewasa), Rp.125.000 (Anak-anak) dan Rp.480.000 (Family/2 dewasa & 2 anak), sedang untuk turis Internasional USD 20 (Dewasa) dan USD 14 (Anak-anak). Biaya tersebut untuk bermain selama 150 menit di 8 tingkatan sirkuit yang memiliki 88 tantangan dan 24 flying fox. Biaya sudah termasuk sewa peralatan keselamatan, air minerl, supporting instruktur profesional, serta asuransi.
# 14              Terminal Wisata Grafika Cikole                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Kawasan Wisata Terpadu yang lebih dikenal dengan nama Terminal Wisata Grafika Cikole ini memadukan wisata kuliner yang ditunjang dengan fasilitas hotel serta menghadirkan keindahan alam karena lokasinya memang berada di kaki Gunung Lembang yang dikenal memiliki panorama alam yang eksotis. Di area perbukitan yang memiliki ketinggian 1.400 meter dpl dengan luas 9 hektar membuat suhu udaraTerminal Wisata Grafika Cikole selalu sejuk. Terlebih di sekelilingnya berbalut pohon-pohon pinus. Keindahan alam di sekeliling tempat Wisata Terpadu ini juga sering dimanfaatkan  untuk pengambilan foto pre-wedding, sedang hotel Grafika Cikole yang ada di lokasi kerapkali disewa oleh pasangan yang sedang menikmati bulan madu.
# 15                                Situ Lembang                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Danau Buatan yang dibuat oleh pemerintah Belanda sekitar tahun 1912 ini berlokasi di 2 kaki pegunungan sekaligus yaitu Gunung Tangkuban Perahu dan Gunung Burangrang. Situ Lembang juga merupakan penampungan air terbesar di Bandung yang airnya dimanfaatkan sebagai bahan baku air bersih. Banyak yang menyebut danau yang berada di ketinggian 1.570 meter dpl ini mirip dengan setting alam yang ada di film “Lord of The Ring”. Pendapat tersebut muncul karena kawasan hutannya yang masih alami dan terjaga keindahannya. Dengan suguhan panorama yang eksotis itulah membuat para wisatawan tidak pernah melewatkan untuk berburu spot menarik untuk dijadikan background foto.
# 16                       Stone Garden Geo Park                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Kawasan gunung batu kapur yang berada pada ketinggian 709 meter dpl ini berada di puncak Gunung Pawon. Dengan luas sekitar 2 hektar tempat ini menyuguhkan keindahan alam sekitar saat dilihat dari ketinggian. Sedang untuk pemandangan yang ditawarkan di lokasi wisata, berupa batu-batu gamping yang berdiri secara alami dengan susunan tidak beraturan, sehingga menciptakan pemandangan yang eksotis. Selanjutnya Halaman Ketiga, Klik:18 – 25 Destinasi Wisata di Bandung Selatan Dekat Stasiun
# 17                                  Bukit Moko                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Di sinilah titik tertinggi Bandung dengan ketinggian 1.500 meter dpl. sehingga merupakan tempat terbaik untuk melihat seluruh wilayah Bandung. Meski berlokasi di titik tertinggi, Anda tidak perlu mencemaskan perut saat berkunjung ke sini, karena di puncak Bukit Moko terdapat sebuah warung yang bernama “Warung Daweung” Bukit Moko merupakan salah satu tempat favorit anak-anak muda yang banyak memenuhi lokasi pada malam – pagi hari, karena pada malam hari mereka dapat menikmati citylight yakni ribuan bintik-bintik cahaya dari kota Bandung yang menciptakan suasana romantis. Sedang pada pagi hari mereka dapat menikmati keindahan sunset yang muncul dari balik gunung.
# 18                        NuArt Sculpture Park                                                                                                                                                                                                                                                                                                                                                                                                                                              NuArt Sculpture Park adalah tempat tinggal sekaligus gallery seni dan museum dari salah satu maestro pemahat kelas dunia asal Indonesia, I Nyoman Nuarta. Salah satu karya fenomenalnya yang sudah dinikmati jutaan orang adalah Patung Garuda Wisnu yang ada di Bali. Berkunjung ke NuArt Sculpture Park dapat menjadi wisata budaya sekaligus wisata edukatif yang akan memperluas pengetahuan Anda tentang dunia seni rupa, sekaligus menikmati karya-karya seni pahat yang mengagumkan. Penataan dekorasi ruangan dan desain outdoor dari landmark ini juga bakal membuat Anda betah berlama-lama di sekitar lokasi. Terdapat beberapa fasilitas yang melengkapi NuArt Sculpture Park, yaitu: “Sculpture Park” yang memajang hasil karya seni patung, “Gallery Nuart Building” yang menjadi ruang pameran, “Nesti” adalah nama cafe yang ada di sini, “Craft Boutique” tempat menjual miniatur karya Nyoman Nuarta dan karya seniman serta pengrajin lokal dan internasional, serta “Workshop” yang merupakan ruang kerja pemilik gallery dan hanya dibuka pada hari Sabtu dan Minggu saja.
# 19                            Pine Forest Camp                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Bermalam di alam bebas dengan fasilitas exclusive camping di area camping ground yang berpagar pohon-pohon pinus tentu bakal menjadi pengalaman yang menyenangkan. Sensasi itulah yang ditawarkan Pine Forest Camp. Selain itu berbagai fasilitas juga telah disiapkan oleh pihak pengelola, seperti area api unggun, jalur tracking, kolam aktifitas, air bersih, gazebo, kamar mandi umum, aula terbuka, mushollah, serta yang lain. Untuk pengunjung yang hanya ingin menikmati keindahan alam sekitar namun tidak berniat untuk bermalam di bawah tenda, tersedia 2 unit villa indoor yang dapat disewa. Dengan fasilitas yang lengkap, berbagai aktifitas dapat digelar di tempat ini, seperti Paintball War Simulations Games, High Rope Course & Flying fox, Outdoor Party and Games, Team Building/Outbond Training, serta Family Gathering/Company Gathering.
# 20                                   Gua Pawon                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Gua Pawon cukup menarik sebagai objek wisata sejarah karena tempat ini merupakan situs purbakala yang menjadi cikal bakal masyarakat Sunda. Lokasi goa seluas 300 meter2ini berada di puncak Bukit Pawon dengan ketinggian 601 meter dpl, dan Bukit Pawon sendiri merupakan tempat penambangan batu kapur. Panjang Goa Pawon sekitar 38 meter, lebar 16 meter dengan ketinggian yang masih belum dapat dipastikan karena atap goa dalam keadaan runtuh. Di dalam goa terdapat beberapa rongga yang menyerupai sebuah yang dilkengkapi dengan jendela alami berukuran besar. Di tempat inilah untuk pertama kalinya ditemukan kerangka manusia purba yang dipercaya menjadi cikal bakal masyarakat Sunda.
# 21                       Taman Bunga Cihideung                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Ruang terbuka yang dipenuhi berbagai jenis bunga dengan bentuk dan warna yang indah, bakal menghipnotis siapapun yang datang ke Taman Bunga Cihideung. Meski disebut Taman Bunga, destinasi ini sebenarnya bukan merupakan taman bunga dalam arti yang sebenarnya, melainkan sebuah perkampungan tepatnya sebuah Desa yang bernama Cihideung. Dimana hampir semua masyarakatnya membudidayakan berbagai jenis bunga dan tanaman hias untuk dijual kepada para wisatawan yang berkunjung ke desa tersebut atau dikirim ke daerah lain. Karena budidaya bunga dan tanaman hias tersebut dilakukan oleh hampir semua warga yang mendiami area seluas 50 hektar, maka begitu memasuki kawasan ini, yang Anda saksikan adalah hamparan taman bunga yang indah dan menawan.
# 22                           Babakan Siliwangi                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Bahkan pada tahun 1920, Babakan Siliwangi yang populer dengan sebutan Baksil telah ditata sedemikian rupa untuk dijadikan kawasan hutan kota sekaligus menjadi perkebunan terbuka untuk masyarakat. Saat ini Baksil menjadi tempat favorit bagi masyarakat Bandung yang ingin menikmati wisata murah meria, karena tanpa harus mengeluarkan biaya transportasi, mereka sudah dapat menikmati suasana yang nyaman dengan pemandangan indah serta udara yang sejuk dan segar. Selain itu, berbagai aktifitas wisata juga digelar secara rutin di Baksil, seperti Jogging Ria, adu kreatifitas membuat sangkar burung, berbagai lomba, festival dan pertunjukan seni, serta kegiatan yang lain. Buat para pecinta fotografi atau mereka yang ingin menghiasi akun instagram dengan gambar-gambar pemandangan alam yang indah, di tempat ini juga banyak terdapat spot-spot menarik untuk pengambilan foto.
# 23                            Bukit Teletubies                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Dinamakan Bukit Teletubbies, karena gundukan-gundukan bukit yang ada di kawasan ini mengingatkan kita pada serial film kartun yang populer di tahun 1990-an yakni film Teletubies. Hanya saja, karena lokasi ini masih belum dikelola secara profesional, membuat fasilitas yang representatif bagi para wisatawanpun masih belum tersedia. Namun demikian hamparan bebukitan yang lapang dengan pemandangan alam yang indah dan masih alami, membuat Bukit Teletubies kerap dijadikan sebagai lokasi perkemahan serta tempat camping anak-anak muda, meski camping ground yang ada masih sebatas area camping alami.
# 24                              Sanghyang Poek                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Sanghyang Poek adalah goa purbakala yang memiliki batu-batu raksasa berwarna putih dengan bentuk yang unik sehingga sangat menarik untuk dijadikan latar belakang foto. Jika masih belum cukup dengan keindahan bebatuan yang ada di luar goa, dapat menyusuri ke bagian dalam goa untuk melihat stalaktit dan stalagmit yang menawan dengan bentuk menyerupai karang di lautan. Di dekat Goa Sanghyang Poek ini terdapat sungai dengan arus yang tidak seberapa deras dan di sungai tersebut bertebaran batu-batu besar berwarna putih yang juga sangat menarik untuk diabadikan dengan kamera. Selanjutnya Halaman Keempat, Klik:26 – 32 Tempat Rekreasi di Bandung Yang Terkenal Edukatif
# 25                             Kawah Rengganis                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Selain Kawah Putih yang mempesona, sekitar kawasan Ciwidey juga memiliki objek wisata Kawah Rengganis yang juga tidak kalah keindahannya. Bahkan ada beberapa kelebihan dari Kawah Rengganis yang tidak terdapat pada Kawah Putih. Dibandingkan dengan Kawah Putih, kawasan Kawah Rengganis lebih rindang dan asri oleh pepohonan serta bebatuan. Bau belerang yang tercium juga tidak seberapa menyengat, dan formasi bebatuan yang mengeluarkan asap juga dapat dijadikan latar belakang foto yang instagramable. Kelebihan lain dari Kawah Rengganis, kawah yang ada di sini bercampur dengan aliran air sungai yang sangat jernih sehingga dapat digunakan untuk mandi dan menyembuhkan beberapa macam penyakit, seperti encok, rematik, penyakit kulit dan melancarkan aliran darah. Bahkan dengan adanya geyser kecil atau mata air panas yang menyembur ke atas dan menciptakan uap panas, membuat Kawah Rengganis dapat dimanfaatkan untuk spa dan sauna alami.
# 26                     Kampung Batu Malakasari  Kampung Batu Malakasari merupakan kawasan wisata alam yang berada di atas lahan seluas 50.000 meter2. Mengusung konsep Geo Wisata dan Eko Wisata, berbagai fasilitas disediakan untuk memanjakan para pengunjung dan wisatawan yang berkunjung ke destinasi ini. Begitu juga dengan anjungan dan wahana yang tersedia, dari waktu ke waktu terus ditambah. Dengan berbagai wahana dan fasilitas yang tersedia tersebut berbagai aktifitas wisata dapat dilakukan oleh para wisatawan, diantaranya melakukan wisata alam dengan mengunjungi wahana persawahan, perkebunan serta wahana danau dan bukit batu. Berwisataedukasifdengan mengunjungi wahana rumah adat Sunda, Beternak unggas dan wahana seni budaya Sunda. Untuk yang berwisata Outbond, tersedia tersedia rumah pohon dan mini flying fox, jaring laba-laba, jembatan Loop Bridge dan Burma Bridge, jembatan goyang, panjat dinding, Kukuyuan, dan Flying fox sepanjang 120 meter. Terdapat pula wisata Fun Games yang menarik untuk dinikmati bersama keluarga seperti Kereta mini, Trampolin, Pancingan Anak, Tangkap kerlinci, Tangkap Belut serta yang lain. Kampung Batu Malakasari juga dilengkapi dengan kolam renang yang dinamakan Tektona Waterpark yang memiliki berbagai jenis kolam yaitu kolam Olimpyc, Kolam Ombak, Kolam Arus, Toots Pool dan Kids Pool. Fasilitas lainnya adalah Gedung Teatrikal Serba Guna yang dipakai untuk menggelar pertunjukan dan aktifitas yang lain, serta fasilitas Food Court yang menyediakan berbagai macam masakan khas Sunda.
# 27                               GunungPuntang                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Wana Wisata Gunung Puntang merupakan salah satu tempat terbaik bagi para pelajar dan mahasiswa yang ingin melakukan aktifitas perkemahan dan camping, karena itu destinasi wisata yang satu ini dikenal pula dengan sebutan Bumi Perkemahan Gunung Puntang. Bagi penggemar hiking, Gunung Puntang juga menjadi tempat yang menarik dan menantang untuk ditaklukkan. Karena kisah-kisah misteri yang menyelimuti gunung ini ditambah kondisi alam yang masih alami dengan rimbun pepohonan yang tinggi serta suhu udara yang dingin membuat pendaki harus memiliki cukup nyali serta fisik yang kuat. Namun, begitu sampai di puncaknya jerih payah yang yang sudah dilakukan, akan tertebus dengan pesona alamnya yang eksotis. Satu lagi yang menjadi daya tarik dari gunung Puntang adalah adanya jejak sejarah zaman kolonialisme Belanda dalam bentuk Goa Belanda yang dulu merupakan stasiun pemancar radio terbesar se-Asia Tenggara dan difungsikan untuk menyebarluaskan informasi ke seluruh dunia, termasuk menyampaikan informasi ke Negeri Belanda.
# 28                               Bukit Bintang                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Pada siang hari kawasan yang berada di Wilayah Bandung sebelah utara ini memang terlihat biasa-biasa saja, namun begitu menjelang sore dan malam hari, daerah perbukitan tersebut berubah 360 derajat menjadi sebuah lokasi yang sangat mempesona. Berada di Bukit Bintang pada malam hari seolah berada di negeri atas awan dengan kerlap-kerlip lampu kota Bandung yang berkilauan layaknya bintang-bintang yang gemerlapan. Dengan dinginnya udara malam yang menyelimuti kawasan tersebut, membuat pemandangan yang eksotis tersebut berpadu dengan suasana yang romantis.
# 29           Desa Wisata Kampung Pasir Angling                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Seperti halnya desa-desa wisata yang lain, daya tarik yang melekat pada Desa Wisata Kampung Pasir Angling terdapat pada kehidupan masyarakatnya yang masih kental memegang adat istiadat dan mempertahankan budaya tradisional. Sehingga berbagai macam pertunjukan kesenian tradisional seringkali digelar di tempat ini, seperti musik kecapi. Meski begitu, bukan berarti masyarakat desa anti terhadap kesenian modern, terbukti rumah-rumah yang ada di sini dihiasi dengan berbagai bentuk lukisan mural yang menghiasi dinding-dinding rumah. Lukisan-lukisan mural itulah yang menjadi objek menarik untuk berfoto selfie bagi para wisatawan yang berkunjung ke sini. Nilai jual lain yang dimiliki Desa Wisata Kampung Pasir Angling adalah lokasinya yang berada di tepi hutan, sehingga udaranya sejuk dan segar dengan panorama indah membalut di sekelilingnya. Beberapa spot wisata juga melengkapi keindahan desa ini, seperti Batu Ngampar, Bukit Tunggul dan Curug Bellarosa.
# 30                             Curug Bellarosa                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Membicarakan Desa Wisata Kampung Pasir Angling rasanya kurang lengkap tanpa menyinggung Curug Bellarosa yang juga dikenal dengan nama Curug Keraton Suntenjaya Cibodas, karena lokasi Air Terjun Keraton ini berada di wilayah Desa Wisata tersebut. Untuk mencapai lokasi Curug Bellarosa, pengunjung harus terlebih dahulu membelah kawasan hutan pinus dengan panorama alamnya yang indah dalam waktu sekitar 30 menit dari desa Sinten Jaya. Satu lagi spot menarik yang ada di lokasi air terjun ini adalah simbol pemersatu cinta yang berupa batu besar berbentuk hati dan dikenal dengan nama Batu Cinta Bellarosa. Batu Cinta itu tempatnya di area yang kerap digunakan sebagai tempat api unggun oleh mereka yang melakukan perkemahan di sini.
# ...
# 51                         Taman Lembah Dewata                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Kawasan wisata Bandung Utara yang memiliki kontur geografis area perbukitan ini nilai jualnya ada pada keindahan alam yang berlatarbelakang danau tadah hujan yang dinamakan Danau Taman Lembah Dewata. Jangan lupa untuk mengabadikan panorama sekeliling dengan kamera, karena banyak spot-spot menawan yang dapat dijumpai di Taman Lembah Dewata. Itu sebabnya tempat wisata ini kerap dijadikan objek pemotretan foto pre-wedding dan menghiasi banyak akun instagram.
# 52                             Balitsa Lembang                                                                                                                                                                                                                                                                                                                                                           Balitsa adalah kependekan dari Balai Penelitian Tanaman dan Sayuran yang merupakan tempat penelitian berbagai macam tanaman sayuran dan tempat pengembangan tanaman hortikultura terbesar di Indonesia. Dengan fungsi yang melekat tersebut membuat Balitsa kerap dijadikan sebagai objek study tour bagi para pelajar dan mahasiswa, tidak hanya yang berasal dari wilayah di sekitar Bandung tapi juga dari berbagai daerah di seluruh penjuru tanah air. Sudah barang tentu suguhan utama bagi wisatawan yang berkunjung ke tempat ini adalah wisata edukasi untuk mempelajari tentang bagaimana proses dan tahapan penelitian berbagai jenis tanaman termasuk tanaman hortikultura. Para pengujung juga dapat melihat-lihat keindahan kebun-kebun sayuran yang ada di Balitsa, seperti kebun tomat, terong, wortel, mentimun, bayam, kacang panjang, Kubis, sawi, bawang putih, bawang merah, kentang, serta yang lain. Selain wisata edukasi, Balitsa juga menyuguhkan wisata alam lewat indahnya panorama sekeliling, utamanya jajaran pohon pinus yang artistis dan eksotis, sehingga kerap dijadikan lokasi pemotretan per-wedding dan banyak menghiasi akun sosial media.
# 53                       Bukit Tunggul Cibodas                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Bukit Tunggul merupakan puncak tertinggi dari gugusan pegunungan yang ada di Bandung utara dengan ketinggian 2.209 meter dpl. Kawasan Bukit Tunggul sebagian besat ditanami dengan tanaman Kina yang dikelola secara resmi oleh PTP Nusantara VII. Selain indahnya hamparan pohon Kina dan sejuknya udara, wisatawan yang datang ke sini juga akan disuguhi wisata air berupa danau yang dikenal dengan nama Situ Sangkuriang Bukit Tunggul. Di sekitar lokasi juga tersedia camping ground, outbond area, wahana permainan anak seperti Flying Fox, High Rope, Spider Web serta yang lain, dan juga fasilitas penginapan buat para wisatawan yang ingin bermalam di Bukit Tunggul.
# 54                                    De Ranch                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Sejak dibuka pada tahun 2007 tempat ini tidak pernah sepi dari pengunjung karena memang menyajikan tempat wisata yang berbeda dari yang lain. Tempat wisata yang menarik untuk dikunjungi bersama keluarga ini menawarkan konsep kehidupan ala Cowboy, sehingga segala sesuatu yang ada di sini semua mengusung identitas cowboy mulai dari property, baju, topi, sepatu sampai dengan sarana transportasi yang mengandalkan kuda. Berbagai macam wahana permainan yang juga bernuansa cowboy dihadirkan di sini, dan bagi mereka yang ingin mencoba wahana tersebut dikenakan biaya tersendiri diluar biaya tiket masuk. Wahana permainan tersebut diantaranya adalah Kuda Tunggang, Delman, Kuda Poni, PoniKidz, Panahan, dan sebagainya. Sedang untuk fasilitas yang tersedia diantaranya adalah: Kursus Menunggang Kuda, Kursus Kusir, Kursus Merawat Kuda, Kursus Memerah Susu Sapi, Kursus Memasak Kue Ala De ranch, Pasar Tanaman Hias, Restoran, Factory Outlet, Toko Souvenir, Track untuk Kursi Roda, Mushollah, Kamar Mandi, dan Tempat Parkir.
# 55                         Dusun Bambu Lembang                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Berlokasi di kaki Gunung Burangrang, kawasan wisata ini mengkolaborasikan wisata kuliner dengan wisata alam dan dilengkapi dengan berbagai macam wahana permainan. Dengan mengusung tema Back to Nature Dusun Bambu Lembang menghadirkan keindahan alam yang natural, dilengkapi cafe, restoran serta villa. Tidak hanya bersantap dengan berbagai macam menu Nusantara dan menu dari manca saja yang ditawarkan tempat ini, tapi juga menawarkan tempat makan yang unik, seperti makan di tempat yang berbentuk mirip dengan sarang burung dan seolah-olah menggelantung di pohon. Halaman Selanjutnya / Kedelapan, Klik:57 – 61 Tempat Wisata di Ciwidey, Lokasi Objek Terbaru 2025
# 56                         Kawah Putih Ciwidey                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Berada di kawasan pegunungan dengan ketinggian 2.400 meter dpl membuat suhu udara di sekitar Kawah Putih Ciwidey cukup dingin dengan kisaran suhu  antara 80– 220Celcius. Namun, dinginnya udara tersebut menjadi tidak terasa tatkala mata menangkap keindahan alam yang luar biasa dari hamparan tanah bercampur belerang berwarna putih yang berpadu sempurna dengan danau yang airnya juga berwarna putih kehijau-hijauan. Menjadi semakin menarik karena warna air danau tersebut dapat berubah-ubah warna sesuai dengan suhu, cuaca dan kandungan kadar belerang. Begitu indahnya Kawah Putih yang sebenarnya merupakan danau yang terbentuk dari letusan Gunung Patuha, membuat tempat ini kerap dijadikan lokasi untuk pembuatan film, hunting foto, objek lukisan, dan berbagai aktifitas wisata seperti soft tracking, mendaki, dan berkuda.
# 57                                 Bukit Jamur                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Didukung lingkungan sekeliling yang hijau alami, membuat keberadaan cemara-cemara kerdil tersebut tidak saja unik dan menarik, tapi juga menawan untuk dilihat. Tidak heran jika tempat ini kerap dijadikan lokasi pengambilan foto pre-wedding.
# 58                             Situ Patenggang                                                                                                                                                                                                                                                                                                                                                                                                                                 “Situ Patenggang” dalam bahasa Sunda memiliki arti “Terpisah”. Nama tersebut disematkan pada situ atau danau, karena keberadaan danau tidak lepas dari kisah perpisahan antara keponakan Prabu Siliwangi yang bernama Ki Santang dengan kekasihnya yang bernama Dewi Rengganis akibat terjadinya peperangan. Sepasang kekasih tersebut selanjutnya saling mencari, hingga akhirnya dipertemukan di bawah sebuah batu besar  yang dinamakan Batu Cinta. Setelah saling bertemu, Dewi Rengganis meminta kepada Ki Santang untuk membuatkan sebuah danau dengan pulau kecil di tengahnya. Ki Santang pun menuruti permintaan tersebut, sehingga akhirnya terciptalah Situ Patenggang dengan daratan kecil di tengahnya yang diberi nama Pulau Sasuka yang artinya Pulau Asmara. Keindahan Situ Patenggang yang lokasinya berada pada ketinggian 1.600 meter dpl tidak perlu diragukan, karena danau ini dikelilingi cagar alam yang memiliki luas 123.077,15 hektar dan hamparan kebuh teh seluas 45.000 hektar. Sehingga kemanapun mata memandang yang tertangkap  adalah hijaunya pepohonan yang menyejukkan.
# 59                                  Ranca Upas                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Sebagai kawasan wisata alam terpadu,  Ranca Upas menyediakan sejumlah fasilitas bagi para wisatawan, diantaranya adalah: camping area, penangkaran rusa, waterboom, kolam pemandian air panas, fun adventure, serta fun games.
# 60  Ciwidey Valley Hot Spring Waterpark Resort                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Destinasi wisata yang memiliki luas 2 hektar ini memadukan unsur tradisional dan modern yang dilengkapi dengan berbagai macam wahana seperti Swimming Pool, Resort, Camping Ground serta Resto. Terdapat 20 kamar cottage standard dan 3 kamar family cottage yang disediakan bagi para wisatawan yang ingin menginap di sini. Sedang untuk wisatawan yang ingin menginap di alam terbuka tersedia 6 kamar standard camping ground ditambah 4 kamar family camping ground. Fasilitas lain yang disediakan bagi para pengunjung diantaranya adalah Wahana Taman Bermain Anak yang berisi ruang labirin,silinder, ayunan, dan balon air, kebun strawberry, sangkar burung raksasa dengan desain yang unik, camping ground ala Indian, serta ruang meeting yang memiliki kapasitas 50 orang lengkap dengan sound system, big screen, dan tentunya view pemandangan alam. Kembali ke Halaman Awal:60 Tempat Wisata di Bandung Yang Lagi Hits 2025: Memukau, Terfavorit Serta Terpopuler

# %%
# Fungsi untuk mengklasifikasikan jenis wisata berdasarkan deskripsi
def jenis_wisata_fix(desc):
    desc = desc.lower()  # Ubah deskripsi jadi huruf kecil untuk mempermudah pencarian kata kunci

    # Kategori: Wisata Alam
    if any(k in desc for k in ["air terjun", "curug", "gunung", "bukit", "lembah", "perbukitan",
                               "danau", "situ", "kawah", "hutan", "goa", "tebing", "taman",
                               "pohon", "pegunungan", "sawah", "rusa", "cemara", "kuda", "kebun"]):
        return "Alam"

    # Kategori: Wisata Seni dan Budaya
    elif any(k in desc for k in ["angklung", "budaya", "wayang", "seni", "instalasi", "lukisan", "patung", "mural"]):
        return "Seni"

    # Kategori: Wisata Hiburan dan Rekreasi
    elif any(k in desc for k in ["taman bermain", "permainan", "wahana", "outbound", "petualangan", "adrenalin"]):
        return "Hiburan"

    # Kategori: Wisata Edukasi dan Ilmiah
    elif any(k in desc for k in ["museum", "perabotan", "galeri", "edukasi", "belajar", "ilmu", "workshop", "observatorium"]):
        return "Edukasi"

    # Kategori lainnya jika tidak sesuai semua
    else:
        return "Lainnya"

# Terapkan fungsi klasifikasi ke setiap deskripsi di dataframe
df_deskripsi["Jenis Wisata"] = df_deskripsi["Deskripsi"].apply(jenis_wisata_fix)

# Tampilkan nama tempat dan jenis wisata yang sudah diklasifikasi
print(df_deskripsi[["Nama Tempat", "Jenis Wisata"]].to_string(index=True))
# Out:
#                                    Nama Tempat Jenis Wisata
# 1                        Curug Tilu Leuwi Opat         Alam
# 2                                 Curug Malela         Alam
# 3                              Gunung Artapela         Alam
# 4                                  Gunung Nini         Alam
# 5                     Saung Angklung Mang Udjo         Seni
# 6                                 Situ Cisanti         Alam
# 7                        Bukit Gantole Cililin         Alam
# 8                                 Curug Cimahi         Alam
# 9                                Situ Cileunca         Alam
# 10                         Ciwangun Indah Camp         Alam
# 11                  Pemandian Air Panas Ciater         Alam
# 12                          Puncak Ciumbuleuit         Alam
# 13              Bandung Treetop Adventure Park      Hiburan
# 14              Terminal Wisata Grafika Cikole         Alam
# 15                                Situ Lembang         Alam
# 16                       Stone Garden Geo Park         Alam
# 17                                  Bukit Moko         Alam
# 18                        NuArt Sculpture Park         Seni
# 19                            Pine Forest Camp         Alam
# 20                                   Gua Pawon         Alam
# 21                       Taman Bunga Cihideung         Alam
# 22                           Babakan Siliwangi         Alam
# 23                            Bukit Teletubies         Alam
# 24                              Sanghyang Poek         Alam
# 25                             Kawah Rengganis         Alam
# 26                     Kampung Batu Malakasari         Alam
# 27                               GunungPuntang         Alam
# 28                               Bukit Bintang         Alam
# 29           Desa Wisata Kampung Pasir Angling         Alam
# 30                             Curug Bellarosa         Alam
# 31                    Sendang Geulis Kahuripan         Alam
# 32                           Amazing Art World         Seni
# 33                           Upside Down World         Seni
# 34                               Curug Bugbrug         Alam
# 35                              Museum Geologi      Edukasi
# 36                      Kebun Binatang Bandung         Alam
# 37                          Kebun Teh Sukawana         Alam
# 38               Taman Hutan Raya Ir.H Djuanda         Alam
# 39                        Trans Studio Bandung      Hiburan
# 40                      Farmhouse Susu Lembang         Alam
# 41                     Gunung Tangkuban Perahu         Alam
# 42                             Floating Market         Alam
# 43                   Taman Miniatur Kereta Api         Alam
# 44                            Sapu Lidi Resort         Alam
# 45                        Jendela Alam Lembang         Alam
# 46                    Kampung Gajah Wonderland      Hiburan
# 47                       Observatorium Bosscha      Edukasi
# 48                                 GunungPutri         Alam
# 49          Maribaya Natural Hot Spring Resort         Alam
# 50                               Taman Begonia         Alam
# 51                         Taman Lembah Dewata         Alam
# 52                             Balitsa Lembang         Alam
# 53                       Bukit Tunggul Cibodas         Alam
# 54                                    De Ranch         Alam
# 55                         Dusun Bambu Lembang         Alam
# 56                         Kawah Putih Ciwidey         Alam
# 57                                 Bukit Jamur         Alam
# 58                             Situ Patenggang         Alam
# 59                                  Ranca Upas         Alam
# 60  Ciwidey Valley Hot Spring Waterpark Resort         Alam

# %%
# Import library visualisasi
import matplotlib.pyplot as plt

# Hitung jumlah tempat untuk setiap jenis wisata
jenis_counts = df_deskripsi["Jenis Wisata"].value_counts()

# Buat figure untuk visualisasi bar chart
plt.figure(figsize=(8, 5))

# Plot bar chart distribusi jenis wisata
jenis_counts.plot(
    kind="bar",
    color="skyblue",      # Warna batang
    edgecolor="black"     # Garis tepi batang
)

# Tambahkan judul dan label sumbu
plt.title("Distribusi Jenis Wisata di Bandung")
plt.xlabel("Jenis Wisata")
plt.ylabel("Jumlah Tempat")

# Atur tampilan label sumbu x agar tidak miring
plt.xticks(rotation=0)

# Atur layout agar tidak terpotong
plt.tight_layout()

# Tampilkan plot
plt.show()

# %% [markdown]
# # Deskripsi
# ## Aktivitas

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)

# %%
pip install nltk scikit-learn
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (3.9.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk) (8.2.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk) (4.67.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords

stopwords_indonesia = stopwords.words('indonesian')

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(stop_words=stopwords_indonesia, max_features=100)
X = vectorizer.fit_transform(df_deskripsi["Deskripsi"])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_extraction/text.py:402: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['baiknya', 'berkali', 'kali', 'kurangnya', 'mata', 'olah', 'sekurang', 'setidak', 'tama', 'tidaknya'] not in stop_words.
#   warnings.warn(

# %%
# Import modul regex
import re

# Fungsi untuk membersihkan teks deskripsi
def clean_text(text):
    text = text.lower()  # Ubah ke huruf kecil semua
    text = re.sub(r'[^a-z\s]', ' ', text)  # Hapus simbol, angka, dan tanda baca
    tokens = text.split()  # Pisahkan kata-kata
    tokens = [t for t in tokens if t not in stopwords_indonesia]  # Hapus stopwords
    return ' '.join(tokens)  # Gabungkan kembali jadi string

# Bersihkan kolom deskripsi dan simpan ke kolom baru
df_deskripsi["Deskripsi Bersih"] = df_deskripsi["Deskripsi"].apply(clean_text)

# Inisialisasi TF-IDF Vectorizer tanpa stop_words (karena sudah dibersihkan manual)
vectorizer = TfidfVectorizer(max_features=100)

# Transformasikan deskripsi bersih menjadi matriks TF-IDF
X = vectorizer.fit_transform(df_deskripsi["Deskripsi Bersih"])

# Cetak hasil vektorisasi (sparse matrix)
print(X)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 973 stored elements and shape (60, 100)>
#   Coords	Values
#   (0, 22)	0.20061410523924667
#   (0, 15)	0.7305334585093012
#   (0, 0)	0.2720224581802783
#   (0, 91)	0.4358358205234326
#   (0, 56)	0.06654043151763278
#   (0, 45)	0.07458299768235696
#   (0, 61)	0.1390718756184438
#   (0, 85)	0.1043619226441859
#   (0, 97)	0.048104356813776734
#   (0, 14)	0.090403135593814
#   (0, 31)	0.09667984778207998
#   (0, 36)	0.08509625105467693
#   (0, 95)	0.2179179102617163
#   (0, 57)	0.0784121186695858
#   (0, 46)	0.1043619226441859
#   (0, 1)	0.09667984778207998
#   (0, 21)	0.10030705261962333
#   (0, 62)	0.1043619226441859
#   (1, 15)	0.38452835079687236
#   (1, 0)	0.6264278709941975
#   (1, 91)	0.6021996278834386
#   (1, 56)	0.12258629270382179
#   (1, 61)	0.2562097248635119
#   (1, 42)	0.12810486243175595
#   (2, 56)	0.1340823361714886
#   :	:
#   (59, 56)	0.16840184076469558
#   (59, 97)	0.12174345809727809
#   (59, 14)	0.45758808885585217
#   (59, 31)	0.4893585436709548
#   (59, 95)	0.13787773984432344
#   (59, 66)	0.10768163801270818
#   (59, 2)	0.15813969547011672
#   (59, 35)	0.09673343497451072
#   (59, 7)	0.08799146368076448
#   (59, 19)	0.1223396359177387
#   (59, 4)	0.10768163801270818
#   (59, 93)	0.13787773984432344
#   (59, 92)	0.1223396359177387
#   (59, 98)	0.20372901524360026
#   (59, 68)	0.09673343497451072
#   (59, 27)	0.09922347076092249
#   (59, 41)	0.13206060945341538
#   (59, 50)	0.1223396359177387
#   (59, 23)	0.2757554796886469
#   (59, 64)	0.13787773984432344
#   (59, 96)	0.22182012079503818
#   (59, 78)	0.2757554796886469
#   (59, 11)	0.13787773984432344
#   (59, 33)	0.13206060945341538
#   (59, 87)	0.13206060945341538

# %%
# Import library untuk clustering
from sklearn.cluster import KMeans

# Inisialisasi dan jalankan algoritma KMeans dengan jumlah cluster tertentu (misal: 6)
kmeans = KMeans(n_clusters=6, random_state=42)

# Lakukan prediksi cluster berdasarkan data TF-IDF
clusters = kmeans.fit_predict(X)

# Tambahkan hasil cluster sebagai kolom baru di dataframe
df_deskripsi["Aktivitas Cluster"] = clusters

# Tampilkan hasil cluster untuk setiap tempat wisata
print(df_deskripsi["Aktivitas Cluster"])
# Out:
# 1     4
# 2     4
# 3     5
# 4     0
# 5     3
# 6     5
# 7     0
# 8     4
# 9     2
# 10    2
# 11    2
# 12    5
# 13    3
# 14    2
# 15    5
# 16    5
# 17    0
# 18    1
# 19    2
# 20    0
# 21    2
# 22    2
# 23    0
# 24    3
# 25    5
# 26    3
# 27    5
# 28    0
# 29    3
# 30    4
# 31    5
# 32    5
# 33    3
# 34    4
# 35    2
# 36    2
# 37    2
# 38    4
# 39    3
# 40    3
# 41    5
# 42    3
# 43    3
# 44    1
# 45    3
# 46    1
# 47    2
# 48    5
# 49    4
# 50    2
# 51    5
# 52    2
# 53    0
# 54    3
# 55    1
# 56    5
# 57    0
# 58    5
# 59    2
# 60    2
# Name: Aktivitas Cluster, dtype: int32

# %%
# Import numpy untuk manipulasi array
import numpy as np

# Ambil daftar istilah (fitur kata) dari TF-IDF vectorizer
terms = vectorizer.get_feature_names_out()

# Urutkan indeks kata di setiap centroid cluster berdasarkan bobot terbesar ke terkecil
order_centroids = kmeans.cluster_centers_.argsort()[:, ::-1]

# Tampilkan 10 kata teratas dari setiap cluster
for i in range(6):
    print(f"\nCluster {i}:")

    # Ambil 10 kata paling representatif untuk cluster ke-i
    top_kata = [terms[ind] for ind in order_centroids[i, :10]]

    # Cetak kata-kata tersebut
    print(", ".join(top_kata))
# Out:
# Cluster 0:
# bukit, lokasi, bandung, ketinggian, meter, kawasan, alami, anak, hamparan, puncak
#
# Cluster 1:
# menu, seni, wisata, makan, wahana, suguhan, orang, kawasan, permainan, ruang
#
# Cluster 2:
# wisata, kebun, alam, bunga, camping, fasilitas, pengunjung, area, taman, ground
#
# Cluster 3:
# anak, wahana, rumah, permainan, wisata, kereta, sunda, api, batu, bandung
#
# Cluster 4:
# terjun, air, curug, meter, kolam, ketinggian, wisata, pohon, panas, batu
#
# Cluster 5:
# gunung, danau, kawah, alam, bandung, air, wisata, pemandangan, mata, puncak

# %%
# Pemetaan cluster numerik ke label aktivitas
cluster_to_label = {
    0: "Hiking / Trekking",
    1: "Hiburan / Kuliner",
    2: "Camping / Alam",
    3: "Hiburan Anak",
    4: "Aktivitas Air",
    5: "Alam Pegunungan"
}

# Tambahkan kolom baru "Aktivitas" berdasarkan hasil mapping dari cluster
df_deskripsi["Aktivitas"] = df_deskripsi["Aktivitas Cluster"].map(cluster_to_label)

# Tampilkan nama tempat beserta label aktivitasnya
print(df_deskripsi[["Nama Tempat", "Aktivitas"]].to_string(index=True))
# Out:
#                                    Nama Tempat          Aktivitas
# 1                        Curug Tilu Leuwi Opat      Aktivitas Air
# 2                                 Curug Malela      Aktivitas Air
# 3                              Gunung Artapela    Alam Pegunungan
# 4                                  Gunung Nini  Hiking / Trekking
# 5                     Saung Angklung Mang Udjo       Hiburan Anak
# 6                                 Situ Cisanti    Alam Pegunungan
# 7                        Bukit Gantole Cililin  Hiking / Trekking
# 8                                 Curug Cimahi      Aktivitas Air
# 9                                Situ Cileunca     Camping / Alam
# 10                         Ciwangun Indah Camp     Camping / Alam
# 11                  Pemandian Air Panas Ciater     Camping / Alam
# 12                          Puncak Ciumbuleuit    Alam Pegunungan
# 13              Bandung Treetop Adventure Park       Hiburan Anak
# 14              Terminal Wisata Grafika Cikole     Camping / Alam
# 15                                Situ Lembang    Alam Pegunungan
# 16                       Stone Garden Geo Park    Alam Pegunungan
# 17                                  Bukit Moko  Hiking / Trekking
# 18                        NuArt Sculpture Park  Hiburan / Kuliner
# 19                            Pine Forest Camp     Camping / Alam
# 20                                   Gua Pawon  Hiking / Trekking
# 21                       Taman Bunga Cihideung     Camping / Alam
# 22                           Babakan Siliwangi     Camping / Alam
# 23                            Bukit Teletubies  Hiking / Trekking
# 24                              Sanghyang Poek       Hiburan Anak
# 25                             Kawah Rengganis    Alam Pegunungan
# 26                     Kampung Batu Malakasari       Hiburan Anak
# 27                               GunungPuntang    Alam Pegunungan
# 28                               Bukit Bintang  Hiking / Trekking
# 29           Desa Wisata Kampung Pasir Angling       Hiburan Anak
# 30                             Curug Bellarosa      Aktivitas Air
# 31                    Sendang Geulis Kahuripan    Alam Pegunungan
# 32                           Amazing Art World    Alam Pegunungan
# 33                           Upside Down World       Hiburan Anak
# 34                               Curug Bugbrug      Aktivitas Air
# 35                              Museum Geologi     Camping / Alam
# 36                      Kebun Binatang Bandung     Camping / Alam
# 37                          Kebun Teh Sukawana     Camping / Alam
# 38               Taman Hutan Raya Ir.H Djuanda      Aktivitas Air
# 39                        Trans Studio Bandung       Hiburan Anak
# 40                      Farmhouse Susu Lembang       Hiburan Anak
# 41                     Gunung Tangkuban Perahu    Alam Pegunungan
# 42                             Floating Market       Hiburan Anak
# 43                   Taman Miniatur Kereta Api       Hiburan Anak
# 44                            Sapu Lidi Resort  Hiburan / Kuliner
# 45                        Jendela Alam Lembang       Hiburan Anak
# 46                    Kampung Gajah Wonderland  Hiburan / Kuliner
# 47                       Observatorium Bosscha     Camping / Alam
# 48                                 GunungPutri    Alam Pegunungan
# 49          Maribaya Natural Hot Spring Resort      Aktivitas Air
# 50                               Taman Begonia     Camping / Alam
# 51                         Taman Lembah Dewata    Alam Pegunungan
# 52                             Balitsa Lembang     Camping / Alam
# 53                       Bukit Tunggul Cibodas  Hiking / Trekking
# 54                                    De Ranch       Hiburan Anak
# 55                         Dusun Bambu Lembang  Hiburan / Kuliner
# 56                         Kawah Putih Ciwidey    Alam Pegunungan
# 57                                 Bukit Jamur  Hiking / Trekking
# 58                             Situ Patenggang    Alam Pegunungan
# 59                                  Ranca Upas     Camping / Alam
# 60  Ciwidey Valley Hot Spring Waterpark Resort     Camping / Alam

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
import pandas as pd

# TF-IDF Vector dari deskripsi
vectorizer = TfidfVectorizer(max_features=100)
X = vectorizer.fit_transform(df_deskripsi['Deskripsi'])

# Clustering jadi 3 kelompok
kmeans = KMeans(n_clusters=3, random_state=42)
df_deskripsi['Keramaian Cluster'] = kmeans.fit_predict(X)

# Lihat hasil awal tiap cluster
for i in range(3):
    print(f"\nCluster {i}")
    print(df_deskripsi[df_deskripsi['Keramaian Cluster'] == i][['Nama Tempat', 'Deskripsi']].head(3))
# Out:
# Cluster 0
#               Nama Tempat                                          Deskripsi
# 4             Gunung Nini  Keindahan sunrise dan sunset hanya salah satu ...
# 7   Bukit Gantole Cililin  Dinamakan Bukit Gantole karena di bukit yang m...
# 20              Gua Pawon  Gua Pawon cukup menarik sebagai objek wisata s...
#
# Cluster 1
#                        Nama Tempat  \
# 5         Saung Angklung Mang Udjo
# 11      Pemandian Air Panas Ciater
# 13  Bandung Treetop Adventure Park
#
#                                             Deskripsi
# 5   Saung Angklung Mang Udjo selain menjadi destin...
# 11  Sumber air panas yang mulai dikembangkan oleh ...
# 13  “Fun, Adventure and Adrenalin” tema itulah yan...
#
# Cluster 2
#              Nama Tempat                                          Deskripsi
# 1  Curug Tilu Leuwi Opat  Dinamakan Curug Tilu (Tiga), karena air terjun...
# 2           Curug Malela  Besar dan mempesona, gambaran itulah yang pant...
# 3        Gunung Artapela  Eksotisme pemandangan alam dengan hamparan hij...

# %%
mapping = {
    0: "Tinggi",
    1: "Sedang",
    2: "Rendah"
}
df_deskripsi["Tingkat Keramaian"] = df_deskripsi["Keramaian Cluster"].map(mapping)
print(df_deskripsi[["Nama Tempat", "Tingkat Keramaian"]].to_string(index=True))
# Out:
#                                    Nama Tempat Tingkat Keramaian
# 1                        Curug Tilu Leuwi Opat            Rendah
# 2                                 Curug Malela            Rendah
# 3                              Gunung Artapela            Rendah
# 4                                  Gunung Nini            Tinggi
# 5                     Saung Angklung Mang Udjo            Sedang
# 6                                 Situ Cisanti            Rendah
# 7                        Bukit Gantole Cililin            Tinggi
# 8                                 Curug Cimahi            Rendah
# 9                                Situ Cileunca            Rendah
# 10                         Ciwangun Indah Camp            Rendah
# 11                  Pemandian Air Panas Ciater            Sedang
# 12                          Puncak Ciumbuleuit            Rendah
# 13              Bandung Treetop Adventure Park            Sedang
# 14              Terminal Wisata Grafika Cikole            Rendah
# 15                                Situ Lembang            Rendah
# 16                       Stone Garden Geo Park            Rendah
# 17                                  Bukit Moko            Rendah
# 18                        NuArt Sculpture Park            Rendah
# 19                            Pine Forest Camp            Rendah
# 20                                   Gua Pawon            Tinggi
# 21                       Taman Bunga Cihideung            Rendah
# 22                           Babakan Siliwangi            Rendah
# 23                            Bukit Teletubies            Tinggi
# 24                              Sanghyang Poek            Rendah
# 25                             Kawah Rengganis            Rendah
# 26                     Kampung Batu Malakasari            Sedang
# 27                               GunungPuntang            Rendah
# 28                               Bukit Bintang            Rendah
# 29           Desa Wisata Kampung Pasir Angling            Rendah
# 30                             Curug Bellarosa            Rendah
# 31                    Sendang Geulis Kahuripan            Rendah
# 32                           Amazing Art World            Rendah
# 33                           Upside Down World            Rendah
# 34                               Curug Bugbrug            Rendah
# 35                              Museum Geologi            Rendah
# 36                      Kebun Binatang Bandung            Rendah
# 37                          Kebun Teh Sukawana            Rendah
# 38               Taman Hutan Raya Ir.H Djuanda            Rendah
# 39                        Trans Studio Bandung            Rendah
# 40                      Farmhouse Susu Lembang            Rendah
# 41                     Gunung Tangkuban Perahu            Rendah
# 42                             Floating Market            Sedang
# 43                   Taman Miniatur Kereta Api            Sedang
# 44                            Sapu Lidi Resort            Rendah
# 45                        Jendela Alam Lembang            Sedang
# 46                    Kampung Gajah Wonderland            Sedang
# 47                       Observatorium Bosscha            Rendah
# 48                                 GunungPutri            Rendah
# 49          Maribaya Natural Hot Spring Resort            Sedang
# 50                               Taman Begonia            Rendah
# 51                         Taman Lembah Dewata            Rendah
# 52                             Balitsa Lembang            Rendah
# 53                       Bukit Tunggul Cibodas            Tinggi
# 54                                    De Ranch            Sedang
# 55                         Dusun Bambu Lembang            Rendah
# 56                         Kawah Putih Ciwidey            Rendah
# 57                                 Bukit Jamur            Rendah
# 58                             Situ Patenggang            Rendah
# 59                                  Ranca Upas            Tinggi
# 60  Ciwidey Valley Hot Spring Waterpark Resort            Tinggi

# %% [markdown]
# # Deskripsi
# ## Sentimen

# %%
def deteksi_sentimen(desc):
    desc = desc.lower()

    positif = [
        "indah", "menawan", "memesona", "bagus", "seru", "asyik",
        "menarik", "keren", "luar biasa", "cantik", "terbaik",
        "nyaman", "unik", "suka", "memuaskan", "tenang", "rekomendasi"
    ]
    negatif = [
        "bahaya", "berbahaya", "sulit", "jauh", "macet", "ramai sekali",
        "tidak nyaman", "kotor", "mahal", "sepi", "biasa saja",
        "kurang menarik", "ribet", "jelek", "membosankan", "mengecewakan"
    ]

    skor = 0
    for kata in positif:
        if kata in desc:
            skor += 1
    for kata in negatif:
        if kata in desc:
            skor -= 1

    if skor > 0:
        return "Positif"
    elif skor < 0:
        return "Negatif"
    else:
        return "Netral"

# %%
df_deskripsi["Sentimen"] = df_deskripsi["Deskripsi"].apply(deteksi_sentimen)
print(df_deskripsi[["Nama Tempat", "Sentimen"]].to_string(index=True))
# Out:
#                                    Nama Tempat Sentimen
# 1                        Curug Tilu Leuwi Opat  Positif
# 2                                 Curug Malela   Netral
# 3                              Gunung Artapela  Positif
# 4                                  Gunung Nini  Positif
# 5                     Saung Angklung Mang Udjo   Netral
# 6                                 Situ Cisanti  Positif
# 7                        Bukit Gantole Cililin   Netral
# 8                                 Curug Cimahi  Positif
# 9                                Situ Cileunca  Positif
# 10                         Ciwangun Indah Camp  Positif
# 11                  Pemandian Air Panas Ciater   Netral
# 12                          Puncak Ciumbuleuit   Netral
# 13              Bandung Treetop Adventure Park   Netral
# 14              Terminal Wisata Grafika Cikole  Positif
# 15                                Situ Lembang  Positif
# 16                       Stone Garden Geo Park  Positif
# 17                                  Bukit Moko  Positif
# 18                        NuArt Sculpture Park   Netral
# 19                            Pine Forest Camp  Positif
# 20                                   Gua Pawon  Positif
# 21                       Taman Bunga Cihideung  Positif
# 22                           Babakan Siliwangi  Positif
# 23                            Bukit Teletubies  Positif
# 24                              Sanghyang Poek  Positif
# 25                             Kawah Rengganis  Positif
# 26                     Kampung Batu Malakasari  Positif
# 27                               GunungPuntang  Positif
# 28                               Bukit Bintang  Negatif
# 29           Desa Wisata Kampung Pasir Angling  Positif
# 30                             Curug Bellarosa  Positif
# 31                    Sendang Geulis Kahuripan  Positif
# 32                           Amazing Art World  Positif
# 33                           Upside Down World   Netral
# 34                               Curug Bugbrug  Negatif
# 35                              Museum Geologi   Netral
# 36                      Kebun Binatang Bandung   Netral
# 37                          Kebun Teh Sukawana  Positif
# 38               Taman Hutan Raya Ir.H Djuanda  Positif
# 39                        Trans Studio Bandung  Negatif
# 40                      Farmhouse Susu Lembang   Netral
# 41                     Gunung Tangkuban Perahu  Positif
# 42                             Floating Market  Positif
# 43                   Taman Miniatur Kereta Api   Netral
# 44                            Sapu Lidi Resort  Positif
# 45                        Jendela Alam Lembang  Positif
# 46                    Kampung Gajah Wonderland  Positif
# 47                       Observatorium Bosscha  Positif
# 48                                 GunungPutri  Positif
# 49          Maribaya Natural Hot Spring Resort  Positif
# 50                               Taman Begonia  Positif
# 51                         Taman Lembah Dewata  Positif
# 52                             Balitsa Lembang  Positif
# 53                       Bukit Tunggul Cibodas  Positif
# 54                                    De Ranch   Netral
# 55                         Dusun Bambu Lembang  Positif
# 56                         Kawah Putih Ciwidey  Positif
# 57                                 Bukit Jamur  Positif
# 58                             Situ Patenggang  Positif
# 59                                  Ranca Upas   Netral
# 60  Ciwidey Valley Hot Spring Waterpark Resort  Positif

# %%
# Fungsi rating berdasarkan sentimen
def rating(row):
    if row["Sentimen"] == "Positif":
        return 4
    elif row["Sentimen"] == "Netral":
        return 3
    else:
        return 0

# Hitung skor dan buat tabel akhir
df_deskripsi["Rating"] = df_deskripsi.apply(rating, axis=1)

tabel_final = df_deskripsi[["Nama Tempat", "Jenis Wisata", "Aktivitas", "Sentimen", "Rating"]]
print(tabel_final.to_string(index=True))
# Out:
#                                    Nama Tempat Jenis Wisata          Aktivitas Sentimen  Rating
# 1                        Curug Tilu Leuwi Opat         Alam      Aktivitas Air  Positif       4
# 2                                 Curug Malela         Alam      Aktivitas Air   Netral       3
# 3                              Gunung Artapela         Alam  Hiking / Trekking  Positif       4
# 4                                  Gunung Nini         Alam  Hiking / Trekking  Positif       4
# 5                     Saung Angklung Mang Udjo         Seni            Belajar   Netral       3
# 6                                 Situ Cisanti         Alam            Berfoto  Positif       4
# 7                        Bukit Gantole Cililin         Alam  Hiking / Trekking   Netral       3
# 8                                 Curug Cimahi         Alam      Aktivitas Air  Positif       4
# 9                                Situ Cileunca         Alam      Aktivitas Air  Positif       4
# 10                         Ciwangun Indah Camp         Alam  Hiking / Trekking  Positif       4
# 11                  Pemandian Air Panas Ciater         Alam      Aktivitas Air   Netral       3
# 12                          Puncak Ciumbuleuit         Alam   Tidak Terdeteksi   Netral       3
# 13              Bandung Treetop Adventure Park      Hiburan   Tidak Terdeteksi   Netral       3
# 14              Terminal Wisata Grafika Cikole         Alam            Kuliner  Positif       4
# 15                                Situ Lembang         Alam      Aktivitas Air  Positif       4
# 16                       Stone Garden Geo Park         Alam            Berfoto  Positif       4
# 17                                  Bukit Moko         Alam            Kuliner  Positif       4
# 18                        NuArt Sculpture Park         Seni            Belajar   Netral       3
# 19                            Pine Forest Camp         Alam      Aktivitas Air  Positif       4
# 20                                   Gua Pawon         Alam            Belajar  Positif       4
# 21                       Taman Bunga Cihideung         Alam   Tidak Terdeteksi  Positif       4
# 22                           Babakan Siliwangi         Alam            Berfoto  Positif       4
# 23                            Bukit Teletubies         Alam            Camping  Positif       4
# 24                              Sanghyang Poek         Alam            Berfoto  Positif       4
# 25                             Kawah Rengganis         Alam      Aktivitas Air  Positif       4
# 26                     Kampung Batu Malakasari         Alam      Aktivitas Air  Positif       4
# 27                               GunungPuntang         Alam  Hiking / Trekking  Positif       4
# 28                               Bukit Bintang         Alam            Berfoto  Negatif       0
# 29           Desa Wisata Kampung Pasir Angling         Alam      Aktivitas Air  Positif       4
# 30                             Curug Bellarosa         Alam      Aktivitas Air  Positif       4
# 31                    Sendang Geulis Kahuripan         Alam      Aktivitas Air  Positif       4
# 32                           Amazing Art World         Seni            Berfoto  Positif       4
# 33                           Upside Down World         Seni            Berfoto   Netral       3
# 34                               Curug Bugbrug         Alam      Aktivitas Air  Negatif       0
# 35                              Museum Geologi      Edukasi            Belajar   Netral       3
# 36                      Kebun Binatang Bandung         Alam      Aktivitas Air   Netral       3
# 37                          Kebun Teh Sukawana         Alam            Camping  Positif       4
# 38               Taman Hutan Raya Ir.H Djuanda         Alam      Aktivitas Air  Positif       4
# 39                        Trans Studio Bandung      Hiburan            Kuliner  Negatif       0
# 40                      Farmhouse Susu Lembang         Alam            Kuliner   Netral       3
# 41                     Gunung Tangkuban Perahu         Alam      Aktivitas Air  Positif       4
# 42                             Floating Market         Alam            Berfoto  Positif       4
# 43                   Taman Miniatur Kereta Api         Alam            Berfoto   Netral       3
# 44                            Sapu Lidi Resort         Alam            Kuliner  Positif       4
# 45                        Jendela Alam Lembang         Alam            Kuliner  Positif       4
# 46                    Kampung Gajah Wonderland      Hiburan            Kuliner  Positif       4
# 47                       Observatorium Bosscha      Edukasi            Belajar  Positif       4
# 48                                 GunungPutri         Alam  Hiking / Trekking  Positif       4
# 49          Maribaya Natural Hot Spring Resort         Alam      Aktivitas Air  Positif       4
# 50                               Taman Begonia         Alam   Tidak Terdeteksi  Positif       4
# 51                         Taman Lembah Dewata         Alam            Berfoto  Positif       4
# 52                             Balitsa Lembang         Alam            Belajar  Positif       4
# 53                       Bukit Tunggul Cibodas         Alam            Camping  Positif       4
# 54                                    De Ranch         Alam            Kuliner   Netral       3
# 55                         Dusun Bambu Lembang         Alam            Kuliner  Positif       4
# 56                         Kawah Putih Ciwidey         Alam  Hiking / Trekking  Positif       4
# 57                                 Bukit Jamur         Alam   Tidak Terdeteksi  Positif       4
# 58                             Situ Patenggang         Alam            Kuliner  Positif       4
# 59                                  Ranca Upas         Alam      Aktivitas Air   Netral       3
# 60  Ciwidey Valley Hot Spring Waterpark Resort         Alam            Camping  Positif       4

# %% [markdown]
# # Deskripsi
# ## Pengelompokkan dengan penambahan kolom tarif

# %%
# Definisikan fungsi untuk mengategorikan tarif berdasarkan isi kolom Harga/Tiket
def kategorikan_tarif(harga):
    # Cek jika datanya kosong atau NaN
    if pd.isna(harga):
        return "Tidak diketahui"

    # Ubah ke huruf kecil untuk memudahkan pencarian kata "gratis"
    harga = str(harga).lower()
    if "gratis" in harga:
        return "Gratis"

    # Ambil semua angka dari string (mengabaikan titik pemisah ribuan)
    angka_list = re.findall(r"\d+", harga.replace(".", ""))
    angka_list = [int(a) for a in angka_list if a.isdigit()]

    # Jika ditemukan angka, ambil harga minimum dan kategorikan
    if angka_list:
        min_harga = min(angka_list)
        if min_harga <= 15000:
            return "Murah"
        elif min_harga <= 30000:
            return "Menengah"
        else:
            return "Mahal"
    else:
        return "Tidak diketahui"

# Terapkan fungsi ke setiap baris kolom Harga/Tiket
df["Kategori Tarif"] = df["Harga/Tiket"].apply(kategorikan_tarif)

# Tampilkan jumlah tempat wisata per kategori tarif
print("Jumlah Wisata per Kategori Tarif:")
print(df["Kategori Tarif"].value_counts())
# Out:
# Jumlah Wisata per Kategori Tarif:
# Kategori Tarif
# Murah              37
# Mahal               8
# Gratis              8
# Tidak diketahui     5
# Menengah            2
# Name: count, dtype: int64

# %%
def kategorikan_tarif(harga):
    if pd.isna(harga):
        return "Tidak diketahui"

    harga = str(harga).lower()
    if "gratis" in harga:
        return "Gratis"

    angka_list = re.findall(r"\d+", harga.replace(".", ""))
    angka_list = [int(a) for a in angka_list if a.isdigit()]

    if angka_list:
        min_harga = min(angka_list)
        if min_harga <= 15000:
            return "Murah"
        elif min_harga <= 30000:
            return "Menengah"
        else:
            return "Mahal"
    else:
        return "Tidak diketahui"

# --- 2. Terapkan ke df utama ---
df["Kategori Tarif"] = df["Harga/Tiket"].apply(kategorikan_tarif)

# --- 3. Bersihkan kolom Nama Tempat agar bisa digabung ---
df["Nama Tempat"] = df["Nama Tempat"].str.strip()
df_deskripsi["Nama Tempat"] = df_deskripsi["Nama Tempat"].str.strip()

# --- 4. Gabungkan dua DataFrame berdasarkan Nama Tempat ---
df_final = df.merge(df_deskripsi[["Nama Tempat", "Sentimen"]], on="Nama Tempat", how="left")

# --- 5. Fungsi rating sentimen ---
def rating_sentimen(row):
    if row["Sentimen"] == "Positif":
        return 2
    elif row["Sentimen"] == "Netral":
        return 1
    else:
        return 0

# --- 6. Fungsi rating tarif ---
def rating_tarif(row):
    kategori = row["Kategori Tarif"]
    if kategori == "Gratis":
        return 2
    elif kategori == "Murah":
        return 1
    elif kategori == "Menengah":
        return 1.5
    elif kategori == "Mahal":
        return 0
    else:
        return 0

# --- 7. Hitung rating dan total ---
df_final["Rating Sentimen"] = df_final.apply(rating_sentimen, axis=1)
df_final["Rating Tarif"] = df_final.apply(rating_tarif, axis=1)
df_final["Rating Total"] = df_final["Rating Sentimen"] + df_final["Rating Tarif"]

# --- 8. Tampilkan hasil akhir ---
tabel_akhir = df_final[[
    "Nama Tempat", "Kategori Tarif", "Sentimen",
    "Rating Tarif", "Rating Sentimen", "Rating Total"
]]
print(tabel_akhir.to_string(index=True))
# Out:
#                                    Nama Tempat   Kategori Tarif Sentimen  Rating Tarif  Rating Sentimen  Rating Total
# 0                        Curug Tilu Leuwi Opat            Murah  Positif           1.0                2           3.0
# 1                                 Curug Malela            Murah   Netral           1.0                1           2.0
# 2                              Gunung Artapela            Murah  Positif           1.0                2           3.0
# 3                                  Gunung Nini            Murah  Positif           1.0                2           3.0
# 4                     Saung Angklung Mang Udjo            Mahal   Netral           0.0                1           1.0
# 5                                 Situ Cisanti            Murah  Positif           1.0                2           3.0
# 6                        Bukit Gantole Cililin           Gratis   Netral           2.0                1           3.0
# 7                                 Curug Cimahi            Murah  Positif           1.0                2           3.0
# 8                                Situ Cileunca            Murah  Positif           1.0                2           3.0
# 9                          Ciwangun Indah Camp            Murah  Positif           1.0                2           3.0
# 10                  Pemandian Air Panas Ciater            Murah   Netral           1.0                1           2.0
# 11                          Puncak Ciumbuleuit  Tidak diketahui   Netral           0.0                1           1.0
# 12              Bandung Treetop Adventure Park            Murah   Netral           1.0                1           2.0
# 13              Terminal Wisata Grafika Cikole           Gratis  Positif           2.0                2           4.0
# 14                                Situ Lembang            Murah  Positif           1.0                2           3.0
# 15                       Stone Garden Geo Park            Murah  Positif           1.0                2           3.0
# 16                                  Bukit Moko           Gratis  Positif           2.0                2           4.0
# 17                        NuArt Sculpture Park           Gratis   Netral           2.0                1           3.0
# 18                            Pine Forest Camp            Mahal  Positif           0.0                2           2.0
# 19                                   Gua Pawon            Murah  Positif           1.0                2           3.0
# 20                       Taman Bunga Cihideung  Tidak diketahui  Positif           0.0                2           2.0
# 21                           Babakan Siliwangi            Murah  Positif           1.0                2           3.0
# 22                            Bukit Teletubies           Gratis  Positif           2.0                2           4.0
# 23                              Sanghyang Poek  Tidak diketahui  Positif           0.0                2           2.0
# 24                             Kawah Rengganis            Murah  Positif           1.0                2           3.0
# 25                     Kampung Batu Malakasari            Mahal  Positif           0.0                2           2.0
# 26                               GunungPuntang            Murah  Positif           1.0                2           3.0
# 27                               Bukit Bintang            Murah  Negatif           1.0                0           1.0
# 28           Desa Wisata Kampung Pasir Angling           Gratis  Positif           2.0                2           4.0
# 29                             Curug Bellarosa            Murah  Positif           1.0                2           3.0
# 30                    Sendang Geulis Kahuripan            Murah  Positif           1.0                2           3.0
# 31                           Amazing Art World            Mahal  Positif           0.0                2           2.0
# 32                           Upside Down World            Mahal   Netral           0.0                1           1.0
# 33                               Curug Bugbrug            Murah  Negatif           1.0                0           1.0
# 34                              Museum Geologi            Murah   Netral           1.0                1           2.0
# 35                      Kebun Binatang Bandung            Murah   Netral           1.0                1           2.0
# 36                          Kebun Teh Sukawana            Murah  Positif           1.0                2           3.0
# 37               Taman Hutan Raya Ir.H Djuanda            Murah  Positif           1.0                2           3.0
# 38                        Trans Studio Bandung            Mahal  Negatif           0.0                0           0.0
# 39                      Farmhouse Susu Lembang            Murah   Netral           1.0                1           2.0
# 40                     Gunung Tangkuban Perahu  Tidak diketahui  Positif           0.0                2           2.0
# 41                             Floating Market            Murah  Positif           1.0                2           3.0
# 42                   Taman Miniatur Kereta Api         Menengah   Netral           1.5                1           2.5
# 43                            Sapu Lidi Resort  Tidak diketahui  Positif           0.0                2           2.0
# 44                        Jendela Alam Lembang            Murah  Positif           1.0                2           3.0
# 45                    Kampung Gajah Wonderland            Murah  Positif           1.0                2           3.0
# 46                       Observatorium Bosscha            Murah  Positif           1.0                2           3.0
# 47                                 GunungPutri            Murah  Positif           1.0                2           3.0
# 48          Maribaya Natural Hot Spring Resort            Mahal  Positif           0.0                2           2.0
# 49                               Taman Begonia            Murah  Positif           1.0                2           3.0
# 50                         Taman Lembah Dewata            Murah  Positif           1.0                2           3.0
# 51                             Balitsa Lembang           Gratis  Positif           2.0                2           4.0
# 52                       Bukit Tunggul Cibodas            Murah  Positif           1.0                2           3.0
# 53                                    De Ranch            Murah   Netral           1.0                1           2.0
# 54                         Dusun Bambu Lembang            Murah  Positif           1.0                2           3.0
# 55                         Kawah Putih Ciwidey         Menengah  Positif           1.5                2           3.5
# 56                                 Bukit Jamur           Gratis  Positif           2.0                2           4.0
# 57                             Situ Patenggang            Murah  Positif           1.0                2           3.0
# 58                                  Ranca Upas            Murah   Netral           1.0                1           2.0
# 59  Ciwidey Valley Hot Spring Waterpark Resort            Mahal  Positif           0.0                2           2.0
